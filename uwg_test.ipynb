# %%
from epw import epw



a=epw()
b=epw()
epw_path_a = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"
epw_path_b = "resources/USA_GA_Atlanta.722190_TMY2.epw"
a.read(epw_path_a)
b.read(epw_path_b)

# Remove extra day in leap year
GT = a.dataframe.drop([i+1417 for i in range(24)])


display(GT)
# Out:
#       Year  Month  Day  Hour  Minute    Data Source and Uncertainty Flags  \
# 0     2020      1    1     1       0  'Created with NREL PSM3 input data'
# 1     2020      1    1     2       0  'Created with NREL PSM3 input data'
# 2     2020      1    1     3       0  'Created with NREL PSM3 input data'
# 3     2020      1    1     4       0  'Created with NREL PSM3 input data'
# 4     2020      1    1     5       0  'Created with NREL PSM3 input data'
# ...    ...    ...  ...   ...     ...                                  ...
# 8779  2020     12   31    20       0  'Created with NREL PSM3 input data'
# 8780  2020     12   31    21       0  'Created with NREL PSM3 input data'
# 8781  2020     12   31    22       0  'Created with NREL PSM3 input data'
# 8782  2020     12   31    23       0  'Created with NREL PSM3 input data'
# 8783  2020     12   31    24       0  'Created with NREL PSM3 input data'
#
#       Dry Bulb Temperature  Dew Point Temperature  Relative Humidity  \
# 0                      1.7                    1.7              99.88
# 1                      1.1                    1.1             100.00
# 2                      0.7                    0.7             100.00
# 3                      0.3                    0.3             100.00
# 4                      0.0                    0.0             100.00
# ...                    ...                    ...                ...
# 8779                   3.8                    2.1              88.40
# 8780                   3.2                    2.0              91.90
# 8781                   2.8                    2.0              94.39
# 8782                   2.4                    1.9              96.81
# 8783                   2.1                    1.8              98.04
#
#       Atmospheric Station Pressure  ...  Ceiling Height  \
# 0                            98300  ...           99999
# 1                            98300  ...           99999
# 2                            98300  ...           99999
# 3                            98300  ...           99999
# 4                            98300  ...           99999
# ...                            ...  ...             ...
# 8779                         98200  ...           99999
# 8780                         98200  ...           99999
# 8781                         98300  ...           99999
# 8782                         98300  ...           99999
# 8783                         98300  ...           99999
#
#       Present Weather Observation  Present Weather Codes  Precipitable Water  \
# 0                             NaN                    NaN                 0.8
# 1                             NaN                    NaN                 0.8
# 2                             NaN                    NaN                 0.8
# 3                             NaN                    NaN                 0.8
# 4                             NaN                    NaN                 0.9
# ...                           ...                    ...                 ...
# 8779                          NaN                    NaN                 0.7
# 8780                          NaN                    NaN                 0.7
# 8781                          NaN                    NaN                 0.7
# 8782                          NaN                    NaN                 0.7
# 8783                          NaN                    NaN                 0.8
#
#       Aerosol Optical Depth  Snow Depth  Days Since Last Snowfall  Albedo  \
# 0                     0.999         999                        99    0.11
# 1                     0.999         999                        99    0.11
# 2                     0.999         999                        99    0.11
# 3                     0.999         999                        99    0.11
# 4                     0.999         999                        99    0.11
# ...                     ...         ...                       ...     ...
# 8779                  0.999         999                        99    0.11
# 8780                  0.999         999                        99    0.11
# 8781                  0.999         999                        99    0.11
# 8782                  0.999         999                        99    0.11
# 8783                  0.999         999                        99    0.11
#
#       Liquid Precipitation Depth  Liquid Precipitation Quantity
# 0                            999                             99
# 1                            999                             99
# 2                            999                             99
# 3                            999                             99
# 4                            999                             99
# ...                          ...                            ...
# 8779                         999                             99
# 8780                         999                             99
# 8781                         999                             99
# 8782                         999                             99
# 8783                         999                             99
#
# [8760 rows x 35 columns]

# %%
vars = ['Year', 'Month', 'Day', 'Hour', 'Minute',
       'Data Source and Uncertainty Flags', 'Dry Bulb Temperature',
       'Dew Point Temperature', 'Relative Humidity',
       'Atmospheric Station Pressure', 'Extraterrestrial Horizontal Radiation',
       'Extraterrestrial Direct Normal Radiation',
       'Horizontal Infrared Radiation Intensity',
       'Global Horizontal Radiation', 'Direct Normal Radiation',
       'Diffuse Horizontal Radiation', 'Global Horizontal Illuminance',
       'Direct Normal Illuminance', 'Diffuse Horizontal Illuminance',
       'Zenith Luminance', 'Wind Direction', 'Wind Speed', 'Total Sky Cover',
       'Opaque Sky Cover (used if Horizontal IR Intensity missing)',
       'Visibility', 'Ceiling Height', 'Present Weather Observation',
       'Present Weather Codes', 'Precipitable Water', 'Aerosol Optical Depth',
       'Snow Depth', 'Days Since Last Snowfall', 'Albedo',
       'Liquid Precipitation Depth', 'Liquid Precipitation Quantity']


idx = 16
print(vars[idx])


dfa = a.dataframe
dfa[vars[idx]].plot(label= "GT", legend=True)

dfb = b.dataframe
dfb[vars[idx]].plot(label= "Airport", legend=True)

# We don't have Global Horizontal Illuminance data from NREL; this might be an issue
# Out:
# Global Horizontal Illuminance
# <Axes: >

# %%
from epw import epw

a=epw()

epw_path_a = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"

a.read(epw_path_a)




a.dataframe['Atmospheric Station Pressure'] = a.dataframe['Atmospheric Station Pressure']*100

display(a.dataframe)

a.write("resources/GT_33.77463936796479_-84.39704008595767_2020_edit.epw")
# Out:
#       Year  Month  Day  Hour  Minute    Data Source and Uncertainty Flags  \
# 0     2020      1    1     1       0  'Created with NREL PSM3 input data'
# 1     2020      1    1     2       0  'Created with NREL PSM3 input data'
# 2     2020      1    1     3       0  'Created with NREL PSM3 input data'
# 3     2020      1    1     4       0  'Created with NREL PSM3 input data'
# 4     2020      1    1     5       0  'Created with NREL PSM3 input data'
# ...    ...    ...  ...   ...     ...                                  ...
# 8779  2020     12   31    20       0  'Created with NREL PSM3 input data'
# 8780  2020     12   31    21       0  'Created with NREL PSM3 input data'
# 8781  2020     12   31    22       0  'Created with NREL PSM3 input data'
# 8782  2020     12   31    23       0  'Created with NREL PSM3 input data'
# 8783  2020     12   31    24       0  'Created with NREL PSM3 input data'
#
#       Dry Bulb Temperature  Dew Point Temperature  Relative Humidity  \
# 0                      1.7                    1.7              99.88
# 1                      1.1                    1.1             100.00
# 2                      0.7                    0.7             100.00
# 3                      0.3                    0.3             100.00
# 4                      0.0                    0.0             100.00
# ...                    ...                    ...                ...
# 8779                   3.8                    2.1              88.40
# 8780                   3.2                    2.0              91.90
# 8781                   2.8                    2.0              94.39
# 8782                   2.4                    1.9              96.81
# 8783                   2.1                    1.8              98.04
#
#       Atmospheric Station Pressure  ...  Ceiling Height  \
# 0                          9830000  ...           99999
# 1                          9830000  ...           99999
# 2                          9830000  ...           99999
# 3                          9830000  ...           99999
# 4                          9830000  ...           99999
# ...                            ...  ...             ...
# 8779                       9820000  ...           99999
# 8780                       9820000  ...           99999
# 8781                       9830000  ...           99999
# 8782                       9830000  ...           99999
# 8783                       9830000  ...           99999
#
#       Present Weather Observation  Present Weather Codes  Precipitable Water  \
# 0                             NaN                    NaN                 0.8
# 1                             NaN                    NaN                 0.8
# 2                             NaN                    NaN                 0.8
# 3                             NaN                    NaN                 0.8
# 4                             NaN                    NaN                 0.9
# ...                           ...                    ...                 ...
# 8779                          NaN                    NaN                 0.7
# 8780                          NaN                    NaN                 0.7
# 8781                          NaN                    NaN                 0.7
# 8782                          NaN                    NaN                 0.7
# 8783                          NaN                    NaN                 0.8
#
#       Aerosol Optical Depth  Snow Depth  Days Since Last Snowfall  Albedo  \
# 0                     0.999         999                        99    0.11
# 1                     0.999         999                        99    0.11
# 2                     0.999         999                        99    0.11
# 3                     0.999         999                        99    0.11
# 4                     0.999         999                        99    0.11
# ...                     ...         ...                       ...     ...
# 8779                  0.999         999                        99    0.11
# 8780                  0.999         999                        99    0.11
# 8781                  0.999         999                        99    0.11
# 8782                  0.999         999                        99    0.11
# 8783                  0.999         999                        99    0.11
#
#       Liquid Precipitation Depth  Liquid Precipitation Quantity
# 0                            999                             99
# 1                            999                             99
# 2                            999                             99
# 3                            999                             99
# 4                            999                             99
# ...                          ...                            ...
# 8779                         999                             99
# 8780                         999                             99
# 8781                         999                             99
# 8782                         999                             99
# 8783                         999                             99
#
# [8784 rows x 35 columns]

# %%
from uwg import UWG
import numpy as np
import math

# Define the .epw, .uwg paths to create an uwg object.
epw_path = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"
#epw_path = "resources/USA_GA_Atlanta.722190_TMY2.epw" # available in resources directory.

# path for Atlanta Airport EPW: Sp24-Microclimate/resources/USA_GA_Atlanta.722190_TMY2.epw
# path for GT Campus EPW: Sp24-Microclimate/resources/GT_33.77463936796479_-84.39704008595767_2020.epw

# Initialize the UWG model by passing parameters as arguments, or relying on defaults
model = UWG.from_param_args(epw_path=epw_path, bldheight=10, blddensity=0.5,
                            vertohor=0.8, grasscover=0.1, treecover=0.1, zone='7') # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

model.generate()
model.simulate()

# Write the simulation result to a file.
model.write_epw()
# Out:
# Simulating new temperature and humidity values for 31 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10
# Simulating Day 11
# Simulating Day 12
# Simulating Day 13
# Simulating Day 14
# Simulating Day 15
# Simulating Day 16
# Simulating Day 17
# Simulating Day 18
# Simulating Day 19
# Simulating Day 20
# Simulating Day 21
# Simulating Day 22
# Simulating Day 23
# Simulating Day 24
# Simulating Day 25
# Simulating Day 26
# Simulating Day 27
# Simulating Day 28
# Simulating Day 29
# Simulating Day 30
# Simulating Day 31
# New climate file is generated at resources\GT_33.77463936796479_-84.39704008595767_2020_UWG.epw.

# %%
def calculate_degree_days(hourly_temps, base_temp=18.3):
    """
    Calculate Heating Degree Days (HDD) and Cooling Degree Days (CDD) from hourly temperature data.

    Parameters:
    - hourly_temps: list of 8760 hourly temperature values in degrees Fahrenheit.
    - base_temp: base temperature for calculating HDD and CDD, default is 18.3°C.

    Returns:
    - A tuple containing total HDD and CDD.
    """
    # Ensure the input list has 8760 values (24 hours * 365 days)
    if len(hourly_temps) != 8760:
        raise ValueError("Input list must contain 8760 hourly temperature values.")

    # Calculate daily average temperatures
    daily_avgs = [sum(hourly_temps[i:i+24])/24 for i in range(0, 8760, 24)]
    # Calculate HDD and CDD

    hdd = sum(base_temp - temp for temp in daily_avgs if temp < base_temp)
    cdd = sum(temp - base_temp for temp in daily_avgs if temp > base_temp)

    return hdd, cdd


# Example hourly temperature data (replace this with your actual data)
hourly_temps = [60] * 8760  # Example data, replace with your real temperatures

# Calculate HDD and CDD
hdd, cdd = calculate_degree_days(hourly_temps)
print(f"Heating Degree Days: {hdd}, Cooling Degree Days: {cdd}")
# Out:
# Heating Degree Days: 0, Cooling Degree Days: 15220.500000000098

# %%
model = UWG.from_param_args(epw_path=epw_path, bldheight=10, blddensity=0.5, vertohor=0.04, grasscover=0.1, treecover=0.1, zone='7', nday= 10) # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

model.generate()
model.simulate()
# Out:
# Simulating new temperature and humidity values for 10 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10

# %%
np.array([1,2,3]) - np.array([3,4,5])
# Out:
# array([-2, -2, -2])

# %%
from epw import epw
from uwg import UWG
import numpy as np
import math
from numba import jit
from SALib.sample import sobol
from SALib.analyze import sobol
from SALib.test_functions import Ishigami
from SALib.sample import morris as ms
from SALib.analyze import morris as ma
from SALib.plotting import morris as mp
from SALib.sample import saltelli
import pandas as pd

# %%
from numba import jit
import numpy as np




@jit(nopython=True)
def rmse(y1, y2):
    return np.linalg.norm(y1 - y2) / np.sqrt(len(y1))


def get_SA_metric(epw_path_before_sim, simulated_UWG_model, days_simulated):
    e=epw()
    e.read(epw_path_before_sim)
    epw_df = e.dataframe
    if len(e.dataframe) > 8760:
        epw_df = e.dataframe.drop([i+1417 for i in range(24)])

    simulated_UWG_model.UCMData[0].canTemp-273.15 # This is the canyon air temperature it seems
    ambTemp = [simulated_UWG_model.UCMData[hour].canTemp-273.15  for hour in range(days_simulated*24) ]

    return rmse(np.array(epw_df['Dry Bulb Temperature'].values[:(24*days_simulated)]), np.array(ambTemp))

get_SA_metric(epw_path_a, model, 10)
# Out:
# 2.2393044445487127

# %%
from SALib.sample import sobol
from SALib.analyze import sobol
from SALib.test_functions import Ishigami
from SALib.sample import morris as ms
from SALib.analyze import morris as ma
from SALib.plotting import morris as mp
from SALib.sample import saltelli
import pandas as pd
import numpy as np

test_problem = {
    'num_vars': 14,  # Number of variables
    'names': [
        # Urban characteristics
        'bldheight', 'blddensity', 'vertohor', 'charlength', 'sensanth',

        # Vegetation parameters
        'treecover', 'grasscover', 'vegstart', 'vegend', 'albveg',
        # Urban climate parameters
        'h_obs', 'h_ubl1', 'h_ubl2', 'windmin'
    ],

    'bounds': [
    # Urban characteristics
    [3, 100],   # bldheight - avg building height
    [0.05, 1],  # blddensity - urban area building plan density
    [0.1, 1],   # vertohor - urban area vertical to horizontal ratio
    [50, 300],     # charlength - dimension of a square that encompasses the whole neighborhood [aka. characteristic length] (m)
    [0, 1],         # sensanth
  
    # Vegetation parameters
    [0, 1],     # treecover - Fraction of the urban ground covered in trees (0-1)
    [0, 1],     # grasscover 
    [1, 12],    # vegstart - The month in which vegetation starts to evapotranspire (leaves are out)
    [1, 12],    # vegend - The month in which vegetation stops evapotranspiring (leaves fall)
    [0, 1],     # albveg - vegetation albedo    
    [0.1,3.9],   # h_obs - rural average obstacle height (m)
    
    # Urban climate parameters
    [0, 2000],  # h_ubl1 - urban boundary layer during the day
    [0, 150],   # h_ubl2 - urban boundary layer during the night
    [1, 20]      # min wind speed (m/s)
    ], 'groups': None
}

# We'll perform a Sobol Sensitivity Analysis below.
# Generate samples
param = saltelli.sample(test_problem, 100, calc_second_order=True)

df = pd.DataFrame(param)
print(df)
# Out:
#              0         1         2           3         4         5         6   \
# 0      4.136719  0.365430  0.363672   97.851562  0.902344  0.675781  0.863281
# 1      5.652344  0.365430  0.363672   97.851562  0.902344  0.675781  0.863281
# 2      4.136719  0.773633  0.363672   97.851562  0.902344  0.675781  0.863281
# 3      4.136719  0.365430  0.609766   97.851562  0.902344  0.675781  0.863281
# 4      4.136719  0.365430  0.363672  138.867188  0.902344  0.675781  0.863281
# ...         ...       ...       ...         ...       ...       ...       ...
# 2995  47.332031  0.632617  0.208984  242.382812  0.386719  0.222656  0.972656
# 2996  47.332031  0.632617  0.208984  242.382812  0.386719  0.222656  0.972656
# 2997  47.332031  0.632617  0.208984  242.382812  0.386719  0.222656  0.972656
# 2998  47.332031  0.632617  0.208984  242.382812  0.386719  0.222656  0.972656
# 2999  47.332031  0.632617  0.208984  242.382812  0.386719  0.222656  0.972656
#
#             7         8         9         10         11          12         13
# 0     3.707031  2.160156  0.816406  2.905469  1476.5625  122.460938  17.699219
# 1     3.707031  2.160156  0.816406  2.905469  1476.5625  122.460938  17.699219
# 2     3.707031  2.160156  0.816406  2.905469  1476.5625  122.460938  17.699219
# 3     3.707031  2.160156  0.816406  2.905469  1476.5625  122.460938  17.699219
# 4     3.707031  2.160156  0.816406  2.905469  1476.5625  122.460938  17.699219
# ...        ...       ...       ...       ...        ...         ...        ...
# 2995  1.386719  3.792969  0.691406  1.688281   101.5625   40.429688  19.777344
# 2996  1.386719  3.792969  0.691406  2.192969   398.4375   40.429688  19.777344
# 2997  1.386719  3.792969  0.691406  2.192969   101.5625    6.445312  19.777344
# 2998  1.386719  3.792969  0.691406  2.192969   101.5625   40.429688   7.753906
# 2999  1.386719  3.792969  0.691406  2.192969   101.5625   40.429688  19.777344
#
# [3000 rows x 14 columns]
# C:\Users\zeyuj\AppData\Local\Temp\ipykernel_9996\1086974346.py:48: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   param = saltelli.sample(test_problem, 100, calc_second_order=True)
# C:\Users\zeyuj\AppData\Roaming\Python\Python311\site-packages\SALib\sample\saltelli.py:109: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (100) is equal to `2^n`.
#
#   warnings.warn(msg)

# %%
rand_values = np.random.uniform(0.1, 0.9, size=(param.shape[0], 3))
param[:, [1, 5, 6]] = rand_values / (rand_values.sum(axis=1, keepdims=True) + 0.01)

df = pd.DataFrame(param, columns=test_problem['names'])
print(df)
# Out:
#       bldheight  blddensity  vertohor  charlength  sensanth  treecover  \
# 0      4.136719    0.399780  0.363672   97.851562  0.902344   0.236007
# 1      5.652344    0.249560  0.363672   97.851562  0.902344   0.292651
# 2      4.136719    0.259483  0.363672   97.851562  0.902344   0.449898
# 3      4.136719    0.156670  0.609766   97.851562  0.902344   0.374443
# 4      4.136719    0.485704  0.363672  138.867188  0.902344   0.332198
# ...         ...         ...       ...         ...       ...        ...
# 2995  47.332031    0.400503  0.208984  242.382812  0.386719   0.425721
# 2996  47.332031    0.158924  0.208984  242.382812  0.386719   0.505584
# 2997  47.332031    0.192247  0.208984  242.382812  0.386719   0.258026
# 2998  47.332031    0.517439  0.208984  242.382812  0.386719   0.145778
# 2999  47.332031    0.128844  0.208984  242.382812  0.386719   0.660873
#
#       grasscover  vegstart    vegend    albveg     h_obs     h_ubl1  \
# 0       0.359397  3.707031  2.160156  0.816406  2.905469  1476.5625
# 1       0.452481  3.707031  2.160156  0.816406  2.905469  1476.5625
# 2       0.284734  3.707031  2.160156  0.816406  2.905469  1476.5625
# 3       0.461911  3.707031  2.160156  0.816406  2.905469  1476.5625
# 4       0.174615  3.707031  2.160156  0.816406  2.905469  1476.5625
# ...          ...       ...       ...       ...       ...        ...
# 2995    0.162523  1.386719  3.792969  0.691406  1.688281   101.5625
# 2996    0.327907  1.386719  3.792969  0.691406  2.192969   398.4375
# 2997    0.543464  1.386719  3.792969  0.691406  2.192969   101.5625
# 2998    0.330196  1.386719  3.792969  0.691406  2.192969   101.5625
# 2999    0.202119  1.386719  3.792969  0.691406  2.192969   101.5625
#
#           h_ubl2    windmin
# 0     122.460938  17.699219
# 1     122.460938  17.699219
# 2     122.460938  17.699219
# 3     122.460938  17.699219
# 4     122.460938  17.699219
# ...          ...        ...
# 2995   40.429688  19.777344
# 2996   40.429688  19.777344
# 2997    6.445312  19.777344
# 2998   40.429688   7.753906
# 2999   40.429688  19.777344
#
# [3000 rows x 14 columns]

# %%
i = 0

bldheight=float(df.iloc[i][0].round(4))
print("bldheight", bldheight)

blddensity=float(df.iloc[i][1].round(4))
print("blddensity", blddensity)

vertohor=float(df.iloc[i][2].round(4))
print("vertohor", vertohor)

charlength=float(df.iloc[i][3].round(4))
print("charlength", charlength)

sensanth=float(df.iloc[i][4].round(4))
print("sensanth", sensanth)

treecover=float(df.iloc[i][5].round(4))
print("treecover", treecover)

grasscover=float(df.iloc[i][6].round(4))
print("grasscover", grasscover)

vegstart=int(df.iloc[i][7])
print("vegstart", vegstart)

vegend=int(df.iloc[i][8])
print("vegend", vegend)

albveg=float(df.iloc[i][9].round(4))
print("albveg", albveg)

h_obs=float(df.iloc[i][10].round(4))
print("h_obs", h_obs)

h_ubl1=float(df.iloc[i][11].round(4))
print("h_ubl1", h_ubl1)

h_ubl2=float(df.iloc[i][12].round(4))
print("h_ubl2", h_ubl2)

windmin=float(df.iloc[i][13].round(4))
print("windmin", windmin)


'''
print("bldheight", bldheight)

print("blddensity", blddensity)

print("vertohor", vertohor)

print("charlength", charlength)

print("sensanth", sensanth)

print("treecover", treecover)

print("grasscover", grasscover)

print("vegstart", vegstart)

print("vegend", vegend)

print("albveg", albveg)

print("h_obs", h_obs)

print("h_ubl1", h_ubl1)

print("h_ubl2", h_ubl2)

print("windmin", windmin)


'''


try:
    model1 = UWG.from_param_args(epw_path=epw_path, bldheight=bldheight, blddensity=blddensity, 
                                    vertohor=vertohor, charlength=charlength, sensanth=sensanth,
                                    treecover=treecover, grasscover=grasscover, vegstart=vegstart, 
                                    vegend=vegend, albveg=albveg, h_obs=h_obs, 
                                    h_ubl1=h_ubl1, h_ubl2=h_ubl2, 
                                    windmin=windmin,
                                    zone='7', nday= 25)
    model1.generate()
    model1.simulate()

except: 
    print("Some issue with combination of inputs --> make sure to handle that correctly")
# Out:
# bldheight 4.1367
# blddensity 0.3998
# vertohor 0.3637
# charlength 97.8516
# sensanth 0.9023
# treecover 0.236
# grasscover 0.3594
# vegstart 3
# vegend 2
# albveg 0.8164
# h_obs 2.9055
# h_ubl1 1476.5625
# h_ubl2 122.4609
# windmin 17.6992
# Simulating new temperature and humidity values for 25 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10
# Simulating Day 11
# Simulating Day 12
# Simulating Day 13
# Simulating Day 14
# Simulating Day 15
# Simulating Day 16
# Simulating Day 17
# Simulating Day 18
# Simulating Day 19
# Simulating Day 20
# Simulating Day 21
# Simulating Day 22
# Simulating Day 23
# Simulating Day 24
# Simulating Day 25

# %%
# Run model (example)
Y = np.zeros([df.shape[0]])
issues = 0
for i, X in enumerate(df.iterrows()):

    bldheight=float(df.iloc[i][0].round(4))

    blddensity=float(df.iloc[i][1].round(4))

    vertohor=float(df.iloc[i][2].round(4))

    charlength=float(df.iloc[i][3].round(4))

    sensanth=float(df.iloc[i][4].round(4))

    treecover=float(df.iloc[i][5].round(4))

    grasscover=float(df.iloc[i][6].round(4))

    vegstart=int(df.iloc[i][7])

    vegend=int(df.iloc[i][8])

    albveg=float(df.iloc[i][9].round(4))

    h_obs=float(df.iloc[i][10].round(4))

    h_ubl1=float(df.iloc[i][11].round(4))

    h_ubl2=float(df.iloc[i][12].round(4))

    windmin=float(df.iloc[i][13].round(4))

    if issues != 0:
        print("Issue in Row: ", i)
        print("\n")
        print("bldheight", bldheight)
        print("blddensity", blddensity)
        print("vertohor", vertohor)
        print("charlength", charlength)
        print("sensanth", sensanth)
        print("treecover", treecover)
        print("grasscover", grasscover)
        print("vegstart", vegstart)
        print("vegend", vegend)
        print("albveg", albveg)
        print("h_obs", h_obs)
        print("h_ubl1", h_ubl1)
        print("h_ubl2", h_ubl2)
        print("windmin", windmin)
        break

    print("###")
    print("RUN", i+1)


    try:    
        model1 = UWG.from_param_args(epw_path=epw_path, bldheight=bldheight, blddensity=blddensity, 
    print("{:28s} {:=5.2f} {:=5.2f} ({:=12.2f})".format(name, s1, st, mean)) 



print("************")

columns = []
bounds = []

for col in test_problem['names']:
    columns.append(col)
    
for b in test_problem['bounds']:
        bounds.append(b) 


rows = []
data =  []    
 
cnt=0
for key, value in Si.items():
    rows.append(key)
    data.append(value.round(3))
    cnt+=1
    if cnt > 3:
        break
        

total_Si, first_Si, second_Si = Si.to_df()
print(first_Si)
print(second_Si)
print(total_Si)


# https://github.com/SALib/SALib/issues/206
# Out:
#                   ST   ST_conf
# bldheight   0.274307  0.263152
# blddensity  0.249842  0.246241
# vertohor    0.366929  0.334816
# charlength  0.484294  0.522818
# sensanth    0.377456  0.374336
# treecover   0.360408  0.351653
# grasscover  0.273465  0.246148
# vegstart    0.259768  0.251448
# vegend      0.316493  0.315952
# albveg      0.289770  0.290156
# h_obs       0.307930  0.297657
# h_ubl1      1.323443  0.541553
# h_ubl2      0.294480  0.299520
# windmin     0.435746  0.412204
#                   S1   S1_conf
# bldheight  -0.036792  0.165487
# blddensity  0.059997  0.112159
# vertohor    0.168689  0.172903
# charlength  0.146421  0.146550
# sensanth    0.053867  0.176103
# treecover   0.051214  0.138042
# grasscover  0.045660  0.159228
# vegstart    0.094606  0.131160
# vegend      0.097733  0.187379
# albveg      0.012669  0.138805
# h_obs       0.051413  0.153336
# h_ubl1      1.206406  1.327871
# h_ubl2      0.025803  0.158469
# windmin     0.085402  0.315505
#                                S2   S2_conf
# (bldheight, blddensity)  0.037558  0.185122
# (bldheight, vertohor)    0.090399  0.217428
# (bldheight, charlength)  0.027180  0.225464
# (bldheight, sensanth)    0.073318  0.233620
# (bldheight, treecover)   0.096255  0.205947
# ...                           ...       ...
# (h_obs, h_ubl2)         -0.085049  0.172176
# (h_obs, windmin)        -0.106942  0.189546
# (h_ubl1, h_ubl2)        -0.810028  1.601316
# (h_ubl1, windmin)       -0.555586  1.851818
# (h_ubl2, windmin)       -0.020543  0.188939
#
# [91 rows x 2 columns]
# Name                           1st   2nd        Total
# bldheight                    -0.04  0.27 (       51.61)
# blddensity                    0.06  0.25 (        0.33)
# vertohor                      0.17  0.37 (        0.55)
# charlength                    0.15  0.48 (      174.69)
# sensanth                      0.05  0.38 (        0.50)
# treecover                     0.05  0.36 (        0.33)
# grasscover                    0.05  0.27 (        0.33)
# vegstart                      0.09  0.26 (        6.50)
# vegend                        0.10  0.32 (        6.51)
# albveg                        0.01  0.29 (        0.50)
# h_obs                         0.05  0.31 (        2.00)
# h_ubl1                        1.21  1.32 (     1000.00)
# h_ubl2                        0.03  0.29 (       74.44)
# windmin                       0.09  0.44 (       10.54)
# ************
#                   S1   S1_conf
# bldheight  -0.036792  0.165487
# blddensity  0.059997  0.112159
# vertohor    0.168689  0.172903
# charlength  0.146421  0.146550
# sensanth    0.053867  0.176103
# treecover   0.051214  0.138042
# grasscover  0.045660  0.159228
# vegstart    0.094606  0.131160
# vegend      0.097733  0.187379
# albveg      0.012669  0.138805
# h_obs       0.051413  0.153336
# h_ubl1      1.206406  1.327871
# h_ubl2      0.025803  0.158469
# windmin     0.085402  0.315505
#                                S2   S2_conf
# (bldheight, blddensity)  0.037558  0.185122
# (bldheight, vertohor)    0.090399  0.217428
# (bldheight, charlength)  0.027180  0.225464
# (bldheight, sensanth)    0.073318  0.233620
# (bldheight, treecover)   0.096255  0.205947
# ...                           ...       ...
# (h_obs, h_ubl2)         -0.085049  0.172176
# (h_obs, windmin)        -0.106942  0.189546
# (h_ubl1, h_ubl2)        -0.810028  1.601316
# (h_ubl1, windmin)       -0.555586  1.851818
# (h_ubl2, windmin)       -0.020543  0.188939
#
# [91 rows x 2 columns]
#                   ST   ST_conf
# bldheight   0.274307  0.263152
# blddensity  0.249842  0.246241
# vertohor    0.366929  0.334816
# charlength  0.484294  0.522818
# sensanth    0.377456  0.374336
# treecover   0.360408  0.351653
# grasscover  0.273465  0.246148
# vegstart    0.259768  0.251448
# vegend      0.316493  0.315952
# albveg      0.289770  0.290156
# h_obs       0.307930  0.297657
# h_ubl1      1.323443  0.541553
# h_ubl2      0.294480  0.299520
# windmin     0.435746  0.412204

# %%
pd.DataFrame(Y)
# Out:
#              0
# 0     1.325570
# 1     1.310591
# 2     1.038320
# 3     1.169000
# 4     1.031111
# ...        ...
# 2995  1.013169
# 2996  0.897891
# 2997  1.544818
# 2998  2.252517
# 2999  0.715044
#
# [3000 rows x 1 columns]

# %%
Si
# Out:
# {'S1': array([-0.03679162,  0.05999685,  0.16868852,  0.14642135,  0.05386711,
#          0.05121424,  0.04566009,  0.09460626,  0.09773294,  0.01266918,
#          0.05141264,  1.20640601,  0.0258035 ,  0.08540161]),
#  'S1_conf': array([0.16548673, 0.11215895, 0.17290333, 0.14655041, 0.17610335,
#         0.13804172, 0.15922762, 0.1311598 , 0.18737856, 0.13880523,
#         0.15333597, 1.3278706 , 0.15846872, 0.315505  ]),
#  'ST': array([0.27430717, 0.24984248, 0.36692854, 0.48429447, 0.3774557 ,
#         0.36040846, 0.27346482, 0.25976784, 0.31649277, 0.28976954,
#         0.30793006, 1.32344295, 0.29447989, 0.43574565]),
#  'ST_conf': array([0.26315158, 0.24624148, 0.33481578, 0.52281809, 0.374336  ,
#         0.35165319, 0.24614796, 0.25144849, 0.31595243, 0.29015614,
#         0.29765729, 0.5415529 , 0.29952032, 0.41220444]),
#  'S2': array([[            nan,  3.75576462e-02,  9.03992936e-02,
#           2.71803508e-02,  7.33183655e-02,  9.62549952e-02,
#           7.10974230e-02, -5.23894759e-03,  1.03303531e-01,
#           1.15288923e-03,  9.02077423e-02, -2.64569961e-04,
#           4.77522196e-02, -4.57299467e-02],
#         [            nan,             nan, -1.07762764e-01,
#          -1.42541721e-02, -9.29206636e-02, -7.85519875e-02,
#          -2.29103279e-02, -5.38165350e-02, -2.78622831e-02,
#          -4.38447010e-02, -3.27290117e-03, -3.82680397e-01,
#          -1.99132033e-02, -7.46686165e-02],
#         [            nan,             nan,             nan,
#          -1.18903301e-01, -2.01052385e-02, -8.87813177e-02,
#          -3.25329048e-02, -5.19083370e-02,  2.34534310e-02,
#          -1.18978024e-01, -4.22748393e-02, -3.71063929e-01,
#          -7.42482603e-02, -1.19168915e-01],

#         [       nan,        nan,        nan,        nan,        nan,
#                 nan,        nan,        nan,        nan,        nan,
#                 nan,        nan,        nan,        nan]])}

# %%
Si_filter = {k: Si[k] for k in ['ST', 'ST_conf', 'S1', 'S1_conf']}

# %%
print(Si_filter)
# Out:
# {'ST': array([0.27430717, 0.24984248, 0.36692854, 0.48429447, 0.3774557 ,
#        0.36040846, 0.27346482, 0.25976784, 0.31649277, 0.28976954,
#        0.30793006, 1.32344295, 0.29447989, 0.43574565]), 'ST_conf': array([0.26315158, 0.24624148, 0.33481578, 0.52281809, 0.374336  ,
#        0.35165319, 0.24614796, 0.25144849, 0.31595243, 0.29015614,
#        0.29765729, 0.5415529 , 0.29952032, 0.41220444]), 'S1': array([-0.03679162,  0.05999685,  0.16868852,  0.14642135,  0.05386711,
#         0.05121424,  0.04566009,  0.09460626,  0.09773294,  0.01266918,
#         0.05141264,  1.20640601,  0.0258035 ,  0.08540161]), 'S1_conf': array([0.16548673, 0.11215895, 0.17290333, 0.14655041, 0.17610335,
#        0.13804172, 0.15922762, 0.1311598 , 0.18737856, 0.13880523,
#        0.15333597, 1.3278706 , 0.15846872, 0.315505  ])}

# %%
Si_filter = {k: Si[k] for k in ['ST', 'ST_conf', 'S1', 'S1_conf']}
Si_df = pd.DataFrame.from_dict(Si_filter)

# %%
print(Si_df.columns)
# Out:
# Index(['ST', 'ST_conf', 'S1', 'S1_conf'], dtype='object')

# %%
print(Si_df.head())  # Print the first few rows of Si_df
print("\n")
print(Si_df.info())  # Print information about Si_df
# Out:
#          ST   ST_conf        S1   S1_conf
# 0  0.274307  0.263152 -0.036792  0.165487
# 1  0.249842  0.246241  0.059997  0.112159
# 2  0.366929  0.334816  0.168689  0.172903
# 3  0.484294  0.522818  0.146421  0.146550
# 4  0.377456  0.374336  0.053867  0.176103
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   ST       14 non-null     float64
#  1   ST_conf  14 non-null     float64
#  2   S1       14 non-null     float64
#  3   S1_conf  14 non-null     float64
# dtypes: float64(4)
# memory usage: 576.0 bytes
# None

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
fig, ax = plt.subplots(1)

indices = Si_df[['S1', 'ST']]
err = Si_df[['S1_conf', 'ST_conf']]

indices.plot.bar(yerr=err.values.T,ax=ax)
fig.set_size_inches(8,4)


ax.set_xticklabels([
    'bldheight', 'blddensity', 'vertohor', 'charlength', 'sensanth',
    'treecover', 'grasscover', 'vegstart', 'vegend', 'albveg',
    'h_obs', 'h_ubl1', 'h_ubl2', 'windmin'
], rotation=45, ha='right')


plt.show()
# Save figure
name = "bar_plot_S1_S2_ST"
#fig.savefig(name + '.pdf', bbox_inches='tight', pad_inches=0.0)

# %%
import itertools
from math import pi
import seaborn as sns
sns.set_style('whitegrid')
from math import pi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def normalize(x, xmin, xmax):
    return (x-xmin)/(xmax-xmin)


def plot_circles(ax, locs, names, max_s, stats, smax, smin, fc, ec, lw,
                 zorder):
    s = np.asarray([stats[name] for name in names])
    s = 0.01 + max_s * np.sqrt(normalize(s, smin, smax))

    fill = True
    for loc, name, si in zip(locs, names, s):
        if fc=='w':
            fill=False
        else:
            ec='none'

        x = np.cos(loc)
        y = np.sin(loc)

        circle = plt.Circle((x,y), radius=si, ec=ec, fc=fc, transform=ax.transData._b,
                            zorder=zorder, lw=lw, fill=True)
        ax.add_artist(circle)


def filter(sobol_indices, names, locs, criterion, threshold):
    if criterion in ['ST', 'S1', 'S2']:
        data = sobol_indices[criterion]
        data = np.abs(data)
        data = data.flatten() # flatten in case of S2
        # TODO:: remove nans

        filtered = ([(name, locs[i]) for i, name in enumerate(names) if
                     data[i]>threshold])
        filtered_names, filtered_locs = zip(*filtered)
    elif criterion in ['ST_conf', 'S1_conf', 'S2_conf']:
        raise NotImplementedError
    else:
        raise ValueError('unknown value for criterion')

    return filtered_names, filtered_locs


def plot_sobol_indices(test_problem, sobol_indices, criterion='ST', threshold=0.01):
    '''plot sobol indices on a radial plot

    Parameters
    ----------
    sobol_indices : dict
                    the return from SAlib
    criterion : {'ST', 'S1', 'S2', 'ST_conf', 'S1_conf', 'S2_conf'}, optional
    threshold : float
                only visualize variables with criterion larger than cutoff

    '''
    max_linewidth_s2 = 15#25*1.8
    max_s_radius = 0.3

    # prepare data
    # use the absolute values of all the indices
    #sobol_indices = {key:np.abs(stats) for key, stats in sobol_indices.items()}

    # dataframe with ST and S1
    sobol_stats = {key:sobol_indices[key] for key in ['ST', 'S1']}
    sobol_stats = pd.DataFrame(sobol_stats, index=test_problem['names'])

    smax = sobol_stats.max().max()
    smin = sobol_stats.min().min()

    # dataframe with s2
    s2 = pd.DataFrame(sobol_indices['S2'], index=test_problem['names'],
                      columns=test_problem['names'])
    s2[s2<0.0]=0. #Set negative values to 0 (artifact from small sample sizes)
    s2max = s2.max().max()
    s2min = s2.min().min()

    names = test_problem['names']
    n = len(names)
   
    ticklocs = np.linspace(0, 2*pi, n+1)
    locs = ticklocs[0:-1]


    filtered_names, filtered_locs = filter(sobol_indices, names, locs,
                                           criterion, threshold)

    # setup figure
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)
    ax.grid(False)
    ax.spines['polar'].set_visible(False)
   
    ax.set_xticks(ticklocs[0:len(names)])

    ax.set_xticklabels(names)
    ax.set_yticklabels([])
    
    ax.set_ylim(top=1.4)
    legend(ax)

    # plot ST
    plot_circles(ax, filtered_locs, filtered_names, max_s_radius,
                 sobol_stats['ST'], smax, smin, 'w', 'k', 1, 9)

    # plot S1
    plot_circles(ax, filtered_locs, filtered_names, max_s_radius,
                 sobol_stats['S1'], smax, smin, 'k', 'k', 1, 10)

    # plot S2
    for name1, name2 in itertools.combinations(zip(filtered_names, filtered_locs), 2):
        name1, loc1 = name1
        name2, loc2 = name2

        weight = s2.loc[name1, name2]
        lw = 0.5+max_linewidth_s2*normalize(weight, s2min, s2max)
        ax.plot([loc1, loc2], [1,1], c='darkgray', lw=lw, zorder=1)

    return fig


from matplotlib.legend_handler import HandlerPatch
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize, trans):
        center = 0.5 * width - 0.5 * xdescent, 0.5 * height - 0.5 * ydescent
        p = plt.Circle(xy=center, radius=orig_handle.radius)
        self.update_prop(p, orig_handle, legend)
        p.set_transform(trans)
        return [p]

def legend(ax):
    some_identifiers = [plt.Circle((0,0), radius=5, color='k', fill=False, lw=1),
                        plt.Circle((0,0), radius=5, color='k', fill=True),
                        plt.Line2D([0,0.5], [0,0.5], lw=8, color='darkgray')]
    ax.legend(some_identifiers, ['ST', 'S1', 'S2'],
              loc=(1,0.75), borderaxespad=0.1, mode='expand',
              handler_map={plt.Circle: HandlerCircle()})

# %%
# %matplotlib inline

fig = plot_sobol_indices(test_problem, Si, criterion='ST', threshold=0.005)
fig.set_size_inches(7,7)
plt.show()
