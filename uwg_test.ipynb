# %%
from epw import epw



a=epw()
b=epw()
epw_path_a = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"
epw_path_b = "resources/USA_GA_Atlanta.722190_TMY2.epw"
a.read(epw_path_a)
b.read(epw_path_b)

# Remove extra day in leap year
GT = a.dataframe.drop([i+1417 for i in range(24)])


display(GT)
# Out:
#       Year  Month  Day  Hour  Minute    Data Source and Uncertainty Flags  \
# 0     2020      1    1     1       0  'Created with NREL PSM3 input data'
# 1     2020      1    1     2       0  'Created with NREL PSM3 input data'
# 2     2020      1    1     3       0  'Created with NREL PSM3 input data'
# 3     2020      1    1     4       0  'Created with NREL PSM3 input data'
# 4     2020      1    1     5       0  'Created with NREL PSM3 input data'
# ...    ...    ...  ...   ...     ...                                  ...
# 8779  2020     12   31    20       0  'Created with NREL PSM3 input data'
# 8780  2020     12   31    21       0  'Created with NREL PSM3 input data'
# 8781  2020     12   31    22       0  'Created with NREL PSM3 input data'
# 8782  2020     12   31    23       0  'Created with NREL PSM3 input data'
# 8783  2020     12   31    24       0  'Created with NREL PSM3 input data'
#
#       Dry Bulb Temperature  Dew Point Temperature  Relative Humidity  \
# 0                      1.7                    1.7              99.88
# 1                      1.1                    1.1             100.00
# 2                      0.7                    0.7             100.00
# 3                      0.3                    0.3             100.00
# 4                      0.0                    0.0             100.00
# ...                    ...                    ...                ...
# 8779                   3.8                    2.1              88.40
# 8780                   3.2                    2.0              91.90
# 8781                   2.8                    2.0              94.39
# 8782                   2.4                    1.9              96.81
# 8783                   2.1                    1.8              98.04
#
#       Atmospheric Station Pressure  ...  Ceiling Height  \
# 0                            98300  ...           99999
# 1                            98300  ...           99999
# 2                            98300  ...           99999
# 3                            98300  ...           99999
# 4                            98300  ...           99999
# ...                            ...  ...             ...
# 8779                         98200  ...           99999
# 8780                         98200  ...           99999
# 8781                         98300  ...           99999
# 8782                         98300  ...           99999
# 8783                         98300  ...           99999
#
#       Present Weather Observation  Present Weather Codes  Precipitable Water  \
# 0                             NaN                    NaN                 0.8
# 1                             NaN                    NaN                 0.8
# 2                             NaN                    NaN                 0.8
# 3                             NaN                    NaN                 0.8
# 4                             NaN                    NaN                 0.9
# ...                           ...                    ...                 ...
# 8779                          NaN                    NaN                 0.7
# 8780                          NaN                    NaN                 0.7
# 8781                          NaN                    NaN                 0.7
# 8782                          NaN                    NaN                 0.7
# 8783                          NaN                    NaN                 0.8
#
#       Aerosol Optical Depth  Snow Depth  Days Since Last Snowfall  Albedo  \
# 0                     0.999         999                        99    0.11
# 1                     0.999         999                        99    0.11
# 2                     0.999         999                        99    0.11
# 3                     0.999         999                        99    0.11
# 4                     0.999         999                        99    0.11
# ...                     ...         ...                       ...     ...
# 8779                  0.999         999                        99    0.11
# 8780                  0.999         999                        99    0.11
# 8781                  0.999         999                        99    0.11
# 8782                  0.999         999                        99    0.11
# 8783                  0.999         999                        99    0.11
#
#       Liquid Precipitation Depth  Liquid Precipitation Quantity
# 0                            999                             99
# 1                            999                             99
# 2                            999                             99
# 3                            999                             99
# 4                            999                             99
# ...                          ...                            ...
# 8779                         999                             99
# 8780                         999                             99
# 8781                         999                             99
# 8782                         999                             99
# 8783                         999                             99
#
# [8760 rows x 35 columns]

# %%
vars = ['Year', 'Month', 'Day', 'Hour', 'Minute',
       'Data Source and Uncertainty Flags', 'Dry Bulb Temperature',
       'Dew Point Temperature', 'Relative Humidity',
       'Atmospheric Station Pressure', 'Extraterrestrial Horizontal Radiation',
       'Extraterrestrial Direct Normal Radiation',
       'Horizontal Infrared Radiation Intensity',
       'Global Horizontal Radiation', 'Direct Normal Radiation',
       'Diffuse Horizontal Radiation', 'Global Horizontal Illuminance',
       'Direct Normal Illuminance', 'Diffuse Horizontal Illuminance',
       'Zenith Luminance', 'Wind Direction', 'Wind Speed', 'Total Sky Cover',
       'Opaque Sky Cover (used if Horizontal IR Intensity missing)',
       'Visibility', 'Ceiling Height', 'Present Weather Observation',
       'Present Weather Codes', 'Precipitable Water', 'Aerosol Optical Depth',
       'Snow Depth', 'Days Since Last Snowfall', 'Albedo',
       'Liquid Precipitation Depth', 'Liquid Precipitation Quantity']


idx = 16
print(vars[idx])


dfa = a.dataframe
dfa[vars[idx]].plot(label= "GT", legend=True)

dfb = b.dataframe
dfb[vars[idx]].plot(label= "Airport", legend=True)

# We don't have Global Horizontal Illuminance data from NREL; this might be an issue
# Out:
# Global Horizontal Illuminance
# <Axes: >

# %%
from epw import epw

a=epw()

epw_path_a = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"

a.read(epw_path_a)




a.dataframe['Atmospheric Station Pressure'] = a.dataframe['Atmospheric Station Pressure']*100

display(a.dataframe)

a.write("resources/GT_33.77463936796479_-84.39704008595767_2020_edit.epw")
# Out:
#       Year  Month  Day  Hour  Minute    Data Source and Uncertainty Flags  \
# 0     2020      1    1     1       0  'Created with NREL PSM3 input data'
# 1     2020      1    1     2       0  'Created with NREL PSM3 input data'
# 2     2020      1    1     3       0  'Created with NREL PSM3 input data'
# 3     2020      1    1     4       0  'Created with NREL PSM3 input data'
# 4     2020      1    1     5       0  'Created with NREL PSM3 input data'
# ...    ...    ...  ...   ...     ...                                  ...
# 8779  2020     12   31    20       0  'Created with NREL PSM3 input data'
# 8780  2020     12   31    21       0  'Created with NREL PSM3 input data'
# 8781  2020     12   31    22       0  'Created with NREL PSM3 input data'
# 8782  2020     12   31    23       0  'Created with NREL PSM3 input data'
# 8783  2020     12   31    24       0  'Created with NREL PSM3 input data'
#
#       Dry Bulb Temperature  Dew Point Temperature  Relative Humidity  \
# 0                      1.7                    1.7              99.88
# 1                      1.1                    1.1             100.00
# 2                      0.7                    0.7             100.00
# 3                      0.3                    0.3             100.00
# 4                      0.0                    0.0             100.00
# ...                    ...                    ...                ...
# 8779                   3.8                    2.1              88.40
# 8780                   3.2                    2.0              91.90
# 8781                   2.8                    2.0              94.39
# 8782                   2.4                    1.9              96.81
# 8783                   2.1                    1.8              98.04
#
#       Atmospheric Station Pressure  ...  Ceiling Height  \
# 0                          9830000  ...           99999
# 1                          9830000  ...           99999
# 2                          9830000  ...           99999
# 3                          9830000  ...           99999
# 4                          9830000  ...           99999
# ...                            ...  ...             ...
# 8779                       9820000  ...           99999
# 8780                       9820000  ...           99999
# 8781                       9830000  ...           99999
# 8782                       9830000  ...           99999
# 8783                       9830000  ...           99999
#
#       Present Weather Observation  Present Weather Codes  Precipitable Water  \
# 0                             NaN                    NaN                 0.8
# 1                             NaN                    NaN                 0.8
# 2                             NaN                    NaN                 0.8
# 3                             NaN                    NaN                 0.8
# 4                             NaN                    NaN                 0.9
# ...                           ...                    ...                 ...
# 8779                          NaN                    NaN                 0.7
# 8780                          NaN                    NaN                 0.7
# 8781                          NaN                    NaN                 0.7
# 8782                          NaN                    NaN                 0.7
# 8783                          NaN                    NaN                 0.8
#
#       Aerosol Optical Depth  Snow Depth  Days Since Last Snowfall  Albedo  \
# 0                     0.999         999                        99    0.11
# 1                     0.999         999                        99    0.11
# 2                     0.999         999                        99    0.11
# 3                     0.999         999                        99    0.11
# 4                     0.999         999                        99    0.11
# ...                     ...         ...                       ...     ...
# 8779                  0.999         999                        99    0.11
# 8780                  0.999         999                        99    0.11
# 8781                  0.999         999                        99    0.11
# 8782                  0.999         999                        99    0.11
# 8783                  0.999         999                        99    0.11
#
#       Liquid Precipitation Depth  Liquid Precipitation Quantity
# 0                            999                             99
# 1                            999                             99
# 2                            999                             99
# 3                            999                             99
# 4                            999                             99
# ...                          ...                            ...
# 8779                         999                             99
# 8780                         999                             99
# 8781                         999                             99
# 8782                         999                             99
# 8783                         999                             99
#
# [8784 rows x 35 columns]

# %%
from uwg import UWG
import numpy as np
import math

# Define the .epw, .uwg paths to create an uwg object.
epw_path = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"
#epw_path = "resources/USA_GA_Atlanta.722190_TMY2.epw" # available in resources directory.

# path for Atlanta Airport EPW: Sp24-Microclimate/resources/USA_GA_Atlanta.722190_TMY2.epw
# path for GT Campus EPW: Sp24-Microclimate/resources/GT_33.77463936796479_-84.39704008595767_2020.epw

# Initialize the UWG model by passing parameters as arguments, or relying on defaults
model = UWG.from_param_args(epw_path=epw_path, bldheight=10, blddensity=0.5,
                            vertohor=0.8, grasscover=0.1, treecover=0.1, zone='7') # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

model.generate()
model.simulate()

# Write the simulation result to a file.
model.write_epw()
# Out:
# Simulating new temperature and humidity values for 31 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10
# Simulating Day 11
# Simulating Day 12
# Simulating Day 13
# Simulating Day 14
# Simulating Day 15
# Simulating Day 16
# Simulating Day 17
# Simulating Day 18
# Simulating Day 19
# Simulating Day 20
# Simulating Day 21
# Simulating Day 22
# Simulating Day 23
# Simulating Day 24
# Simulating Day 25
# Simulating Day 26
# Simulating Day 27
# Simulating Day 28
# Simulating Day 29
# Simulating Day 30
# Simulating Day 31
# New climate file is generated at resources/GT_33.77463936796479_-84.39704008595767_2020_UWG.epw.

# %%
def calculate_degree_days(hourly_temps, base_temp=18.3):
    """
    Calculate Heating Degree Days (HDD) and Cooling Degree Days (CDD) from hourly temperature data.

    Parameters:
    - hourly_temps: list of 8760 hourly temperature values in degrees Fahrenheit.
    - base_temp: base temperature for calculating HDD and CDD, default is 18.3°C.

    Returns:
    - A tuple containing total HDD and CDD.
    """
    # Ensure the input list has 8760 values (24 hours * 365 days)
    if len(hourly_temps) != 8760:
        raise ValueError("Input list must contain 8760 hourly temperature values.")

    # Calculate daily average temperatures
    daily_avgs = [sum(hourly_temps[i:i+24])/24 for i in range(0, 8760, 24)]

    # Calculate HDD and CDD
    hdd = sum(base_temp - temp for temp in daily_avgs if temp < base_temp)
    cdd = sum(temp - base_temp for temp in daily_avgs if temp > base_temp)

    return hdd, cdd


# Example hourly temperature data (replace this with your actual data)
hourly_temps = [60] * 8760  # Example data, replace with your real temperatures

# Calculate HDD and CDD
hdd, cdd = calculate_degree_days(hourly_temps)
print(f"Heating Degree Days: {hdd}, Cooling Degree Days: {cdd}")
# Out:
# Heating Degree Days: 0, Cooling Degree Days: 15220.500000000098

# %%
model = UWG.from_param_args(epw_path=epw_path, bldheight=10, blddensity=0.5, vertohor=0.8, grasscover=0.1, treecover=0.1, zone='7', nday= 10) # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

model.generate()
model.simulate()
# Out:
# Simulating new temperature and humidity values for 10 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10

# %%
cdd, hdd = calculate_degree_days(ambTemp)
cdd, hdd
# Out:
# (1129.364483526004, 1386.8472906963268)

# %%
np.array([1,2,3]) - np.array([3,4,5])
# Out:
# array([-2, -2, -2])

# %%
from numba import jit
import numpy as np


@jit(nopython=True)
def rmse(y1, y2):
    return np.linalg.norm(y1 - y2) / np.sqrt(len(y1))


def get_SA_metric(epw_path_before_sim, simulated_UWG_model, days_simulated):
    e=epw()
    e.read(epw_path_before_sim)
    epw_df = e.dataframe
    if len(e.dataframe) > 8760:
        epw_df = e.dataframe.drop([i+1417 for i in range(24)])

    simulated_UWG_model.UCMData[0].canTemp-273.15 # This is the canyon air temperature it seems
    ambTemp = [model.UCMData[hour].canTemp-273.15  for hour in range(days_simulated*24) ]

    return rmse(np.array(epw_df['Dry Bulb Temperature'].values[:(24*days_simulated)]), np.array(ambTemp))

get_SA_metric(epw_path_a, model, 10)
# Out:
# 2.23930444454928

# %%
from SALib.sample import sobol
from SALib.analyze import sobol
from SALib.test_functions import Ishigami
from SALib.sample import morris as ms
from SALib.analyze import morris as ma
from SALib.plotting import morris as mp
import pandas as pd

# Initialize the UWG model by passing parameters as arguments, or relying on defaults
#model = UWG.from_param_args(epw_path=epw_path, bldheight=10, blddensity=0.5,
#                            vertohor=0.8, grasscover=0.1, treecover=0.1, zone='7') # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

# Define the model inputs
problem = {
    'num_vars': 5,
    'names': ['bldheight', 'blddensity', 'vertohor', 'grasscover', 'treecover'],
    'bounds': [[3,100],
               [0.05, 1],
               [0.1, 1],
               [0, 1],
               [0, 1],
               ],
    # I don't want to group any of these variables together
    'groups': None
}


# We'll perform a Sobol Sensitivity Analysis below.


# Generate samples
param = saltelli.sample(problem, 100, calc_second_order=False)
pd.DataFrame(param)
# Out:
# /var/folders/97/v5lvp9nx3ks37kdf8m7qgyl80000gp/T/ipykernel_62270/963608285.py:32: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   param = saltelli.sample(problem, 100, calc_second_order=False)
# /Users/patrickkastner/anaconda3/envs/datascience/lib/python3.9/site-packages/SALib/sample/saltelli.py:109: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (100) is equal to `2^n`.
#
#   warnings.warn(msg)
#              0         1         2         3         4
# 0     4.136719  0.365430  0.363672  0.191406  0.902344
# 1    68.550781  0.365430  0.363672  0.191406  0.902344
# 2     4.136719  0.870117  0.363672  0.191406  0.902344
# 3     4.136719  0.365430  0.321484  0.191406  0.902344
# 4     4.136719  0.365430  0.363672  0.105469  0.902344
# ..         ...       ...       ...       ...       ...
# 695  30.660156  0.506445  0.933203  0.667969  0.144531
# 696  30.660156  0.729102  0.905078  0.667969  0.144531
# 697  30.660156  0.729102  0.933203  0.097656  0.144531
# 698  30.660156  0.729102  0.933203  0.667969  0.511719
# 699  46.574219  0.506445  0.905078  0.097656  0.511719
#
# [700 rows x 5 columns]

# %%
problem
# Out:
# {'num_vars': 5,
#  'names': ['bldheight', 'blddensity', 'vertohor', 'grasscover', 'treecover'],
#  'bounds': [[3, 100], [0.05, 1], [0.1, 1], [0, 1], [0, 1]],
#  'groups': None,
#  'sample_scaled': True}

# %%
#filter values that won't work (some inputs need to be smaller than 1 when summed up)
FILTER = pd.DataFrame(param).iloc[:,[1,3,4]].sum(axis=1) < 1
SAMPLE = pd.DataFrame(param)[FILTER]
SAMPLE

#SAMPLE = pd.DataFrame(param)
# Out:
#              0         1         2         3         4
# 14   76.886719  0.127930  0.138672  0.441406  0.152344
# 15   44.300781  0.127930  0.138672  0.441406  0.152344
# 17   76.886719  0.127930  0.996484  0.441406  0.152344
# 19   76.886719  0.127930  0.138672  0.441406  0.066406
# 37   89.011719  0.276367  0.476172  0.316406  0.027344
# ..         ...       ...       ...       ...       ...
# 625  68.550781  0.105664  0.609766  0.746094  0.097656
# 629  96.589844  0.105664  0.666016  0.675781  0.214844
# 662  56.425781  0.268945  0.947266  0.050781  0.222656
# 691  79.160156  0.254102  0.483203  0.167969  0.011719
# 697  30.660156  0.729102  0.933203  0.097656  0.144531
#
# [107 rows x 5 columns]

# %%
SAMPLE.iloc[0,:]
# Out:
# 0    76.886719
# 1     0.127930
# 2     0.138672
# 3     0.441406
# 4     0.152344
# Name: 14, dtype: float64

# %%
model = UWG.from_param_args(epw_path=epw_path, bldheight=76, blddensity=0.08, vertohor=0.13, grasscover=0.44, treecover=0.15, zone='7', nday= 10) # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/
model.generate()
model.simulate()
# Out:
# Simulating new temperature and humidity values for 10 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10

# %%
i = 0

bldheight=float(SAMPLE.iloc[i][0].round(4))
print("bldheight", bldheight)

blddensity=float(SAMPLE.iloc[i][1].round(4))
print("blddensity", blddensity)

vertohor=float(SAMPLE.iloc[i][2].round(4))
print("vertohor", vertohor)

grasscover=float(SAMPLE.iloc[i][3].round(4))
print("grasscover", grasscover)

treecover=float(SAMPLE.iloc[i][4].round(4))
print("treecover", treecover)



try:
    model1 = UWG.from_param_args(epw_path=epw_path, bldheight=bldheight, blddensity=blddensity, vertohor=vertohor, grasscover=grasscover, treecover=treecover, zone='7', nday= 10) # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

    model1.generate()
    model1.simulate()
except: 
    print("Some issue with combination of inputs --> make sure how to handle that correctly")
# Out:
# bldheight 76.8867
# blddensity 0.1279
# vertohor 0.1387
# grasscover 0.4414
# treecover 0.1523
# Simulating new temperature and humidity values for 10 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10

# %%
sim_days = 1


# Run model (example)
Y = np.zeros([SAMPLE.shape[0]])

for i, X in enumerate(SAMPLE.iterrows()):

    ###
    print("###")
    print("RUN", i)

    print("bldheight", bldheight)

    blddensity=float(SAMPLE.iloc[i][1].round(4))
    print("blddensity", blddensity)

    vertohor=float(SAMPLE.iloc[i][2].round(4))
    print("vertohor", vertohor)

    grasscover=float(SAMPLE.iloc[i][3].round(4))
    print("grasscover", grasscover)

    treecover=float(SAMPLE.iloc[i][4].round(4))
    print("treecover", treecover)

    try:    

        model1 = UWG.from_param_args(epw_path=epw_path, bldheight=bldheight, blddensity=blddensity, vertohor=vertohor, grasscover=grasscover, treecover=treecover, zone='7', nday= sim_days) # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

        model1.generate()
        model1.simulate()
        
        Y[i] = get_SA_metric(epw_path_a, model1, sim_days)
    
    except: 
        Y[i] = None
        print("Some issue with inputs.")
# Out:
# ###
# RUN 0
# bldheight 76.8867
# blddensity 0.1279
# vertohor 0.1387
# grasscover 0.4414
# treecover 0.1523
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 1
# bldheight 76.8867
# blddensity 0.1279
# vertohor 0.1387
# grasscover 0.4414
# treecover 0.1523
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 2
# bldheight 76.8867
# blddensity 0.1279
# vertohor 0.9965
# grasscover 0.4414
# treecover 0.1523
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 3
# bldheight 76.8867
# blddensity 0.1279
# vertohor 0.1387
# grasscover 0.4414
# treecover 0.0664
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 4
# bldheight 76.8867
# blddensity 0.2764
# vertohor 0.4762
# grasscover 0.3164
# treecover 0.0273
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 5
# bldheight 76.8867
# blddensity 0.4842
# vertohor 0.7012
# grasscover 0.2305
# treecover 0.2773
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 6
# bldheight 76.8867
# blddensity 0.0686
# vertohor 0.7574
# grasscover 0.2539
# treecover 0.4648
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 7
# bldheight 76.8867
# blddensity 0.0686
# vertohor 0.7574
# grasscover 0.2539
# treecover 0.4648
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 8
# bldheight 76.8867
# blddensity 0.0686
# vertohor 0.8277
# grasscover 0.2539
# treecover 0.4648
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 9
# bldheight 76.8867
# blddensity 0.0686
# vertohor 0.7574
# grasscover 0.2539
# treecover 0.5039
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 10
# bldheight 76.8867
# blddensity 0.217
# vertohor 0.3777
# grasscover 0.418
# treecover 0.0039
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 11
# bldheight 76.8867
# blddensity 0.3061
# vertohor 0.9824
# grasscover 0.0039
# treecover 0.2539
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 12
# bldheight 76.8867
# blddensity 0.4248
# vertohor 0.1949
# grasscover 0.043
# treecover 0.0898
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 13
# bldheight 76.8867
# blddensity 0.8107
# vertohor 0.2652
# grasscover 0.043
# treecover 0.1289
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 14
# bldheight 76.8867
# blddensity 0.0982
# vertohor 0.8699
# grasscover 0.3789
# treecover 0.3398
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 15
# bldheight 76.8867
# blddensity 0.0982
# vertohor 0.4902
# grasscover 0.293
# treecover 0.3789
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 16
# bldheight 76.8867
# blddensity 0.692
# vertohor 0.7293
# grasscover 0.0977
# treecover 0.1836
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 17
# bldheight 76.8867
# blddensity 0.692
# vertohor 0.7293
# grasscover 0.0977
# treecover 0.1836
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 18
# bldheight 76.8867
# blddensity 0.692
# vertohor 0.4621
# grasscover 0.0977
# treecover 0.1836
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 19
# bldheight 76.8867
# blddensity 0.1279
# vertohor 0.2371
# grasscover 0.6367
# treecover 0.2227
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 20
# bldheight 76.8867
# blddensity 0.0982
# vertohor 0.8418
# grasscover 0.2227
# treecover 0.0586
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 21
# bldheight 76.8867
# blddensity 0.0982
# vertohor 0.8418
# grasscover 0.2227
# treecover 0.0586
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 22
# bldheight 76.8867
# blddensity 0.4842
# vertohor 0.8418
# grasscover 0.2227
# treecover 0.0586
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 23
# bldheight 76.8867
# blddensity 0.0982
# vertohor 0.7996
# grasscover 0.2227
# treecover 0.0586
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 24
# bldheight 76.8867
# blddensity 0.0982
# vertohor 0.8418
# grasscover 0.2617
# treecover 0.0586
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 25
# bldheight 76.8867
# blddensity 0.0982
# vertohor 0.8418
# grasscover 0.2227
# treecover 0.5977
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 26
# bldheight 76.8867
# blddensity 0.6623
# vertohor 0.6309
# grasscover 0.0742
# treecover 0.1602
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 27
# bldheight 76.8867
# blddensity 0.1576
# vertohor 0.448
# grasscover 0.0352
# treecover 0.3711
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 28
# bldheight 76.8867
# blddensity 0.1576
# vertohor 0.448
# grasscover 0.0352
# treecover 0.3711
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 29
# bldheight 76.8867
# blddensity 0.3061
# vertohor 0.448
# grasscover 0.0352
# treecover 0.3711
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 30
# bldheight 76.8867
# blddensity 0.1576
# vertohor 0.9684
# grasscover 0.0352
# treecover 0.3711
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 31
# bldheight 76.8867
# blddensity 0.1576
# vertohor 0.448
# grasscover 0.4492
# treecover 0.3711
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 32
# bldheight 76.8867
# blddensity 0.1576
# vertohor 0.448
# grasscover 0.0352
# treecover 0.0352
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 33
# bldheight 76.8867
# blddensity 0.3061
# vertohor 0.9684
# grasscover 0.4492
# treecover 0.0352
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 34
# bldheight 76.8867
# blddensity 0.0686
# vertohor 0.223
# grasscover 0.2852
# treecover 0.6211
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 35
# bldheight 76.8867
# blddensity 0.3506
# vertohor 0.7715
# grasscover 0.1523
# treecover 0.0117
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 36
# bldheight 76.8867
# blddensity 0.3506
# vertohor 0.3918
# grasscover 0.1523
# treecover 0.1133
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 37
# bldheight 76.8867
# blddensity 0.4693
# vertohor 0.5043
# grasscover 0.0273
# treecover 0.4883
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 38
# bldheight 76.8867
# blddensity 0.2318
# vertohor 0.209
# grasscover 0.1133
# treecover 0.3867
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 39
# bldheight 76.8867
# blddensity 0.2318
# vertohor 0.209
# grasscover 0.1133
# treecover 0.3867
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 40
# bldheight 76.8867
# blddensity 0.2318
# vertohor 0.209
# grasscover 0.1133
# treecover 0.3867
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 41
# bldheight 76.8867
# blddensity 0.2318
# vertohor 0.7293
# grasscover 0.1133
# treecover 0.3867
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 42
# bldheight 76.8867
# blddensity 0.2912
# vertohor 0.1527
# grasscover 0.0898
# treecover 0.3242
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 43
# bldheight 76.8867
# blddensity 0.0537
# vertohor 0.3777
# grasscover 0.5508
# treecover 0.3008
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 44
# bldheight 76.8867
# blddensity 0.5287
# vertohor 0.8277
# grasscover 0.0508
# treecover 0.0742
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 45
# bldheight 76.8867
# blddensity 0.5287
# vertohor 0.8277
# grasscover 0.0508
# treecover 0.0742
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 46
# bldheight 76.8867
# blddensity 0.6475
# vertohor 0.8277
# grasscover 0.0508
# treecover 0.0742
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 47
# bldheight 76.8867
# blddensity 0.5287
# vertohor 0.223
# grasscover 0.0508
# treecover 0.0742
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 48
# bldheight 76.8867
# blddensity 0.5287
# vertohor 0.8277
# grasscover 0.3398
# treecover 0.0742
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 49
# bldheight 76.8867
# blddensity 0.1725
# vertohor 0.7152
# grasscover 0.1758
# treecover 0.1992
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 50
# bldheight 76.8867
# blddensity 0.1725
# vertohor 0.7152
# grasscover 0.1758
# treecover 0.1992
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 51
# bldheight 76.8867
# blddensity 0.0537
# vertohor 0.7152
# grasscover 0.1758
# treecover 0.1992
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 52
# bldheight 76.8867
# blddensity 0.1725
# vertohor 0.5605
# grasscover 0.1758
# treecover 0.1992
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 53
# bldheight 76.8867
# blddensity 0.1725
# vertohor 0.7152
# grasscover 0.1758
# treecover 0.1758
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 54
# bldheight 76.8867
# blddensity 0.1428
# vertohor 0.1246
# grasscover 0.582
# treecover 0.043
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 55
# bldheight 76.8867
# blddensity 0.1428
# vertohor 0.8137
# grasscover 0.1211
# treecover 0.457
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 56
# bldheight 76.8867
# blddensity 0.2021
# vertohor 0.7996
# grasscover 0.332
# treecover 0.293
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 57
# bldheight 76.8867
# blddensity 0.2021
# vertohor 0.7996
# grasscover 0.332
# treecover 0.293
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 58
# bldheight 76.8867
# blddensity 0.2021
# vertohor 0.5887
# grasscover 0.332
# treecover 0.293
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 59
# bldheight 76.8867
# blddensity 0.2021
# vertohor 0.7996
# grasscover 0.3711
# treecover 0.293
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 60
# bldheight 76.8867
# blddensity 0.2021
# vertohor 0.7996
# grasscover 0.332
# treecover 0.207
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 61
# bldheight 76.8867
# blddensity 0.2615
# vertohor 0.9262
# grasscover 0.2461
# treecover 0.082
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 62
# bldheight 76.8867
# blddensity 0.2615
# vertohor 0.5184
# grasscover 0.3945
# treecover 0.1055
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 63
# bldheight 76.8867
# blddensity 0.2615
# vertohor 0.5184
# grasscover 0.3945
# treecover 0.1055
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 64
# bldheight 76.8867
# blddensity 0.2615
# vertohor 0.7574
# grasscover 0.3945
# treecover 0.1055
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 65
# bldheight 76.8867
# blddensity 0.2615
# vertohor 0.5184
# grasscover 0.4336
# treecover 0.1055
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 66
# bldheight 76.8867
# blddensity 0.3803
# vertohor 0.8559
# grasscover 0.5195
# treecover 0.0195
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 67
# bldheight 76.8867
# blddensity 0.0834
# vertohor 0.8699
# grasscover 0.0586
# treecover 0.5195
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 68
# bldheight 76.8867
# blddensity 0.3209
# vertohor 0.1809
# grasscover 0.2695
# treecover 0.2305
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 69
# bldheight 76.8867
# blddensity 0.2541
# vertohor 0.8066
# grasscover 0.3945
# treecover 0.0586
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 70
# bldheight 76.8867
# blddensity 0.7291
# vertohor 0.4129
# grasscover 0.1523
# treecover 0.0039
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 71
# bldheight 76.8867
# blddensity 0.358
# vertohor 0.3004
# grasscover 0.0273
# treecover 0.1289
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 72
# bldheight 76.8867
# blddensity 0.358
# vertohor 0.3004
# grasscover 0.0273
# treecover 0.1289
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 73
# bldheight 76.8867
# blddensity 0.1354
# vertohor 0.3004
# grasscover 0.0273
# treecover 0.1289
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 74
# bldheight 76.8867
# blddensity 0.358
# vertohor 0.9191
# grasscover 0.0273
# treecover 0.1289
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 75
# bldheight 76.8867
# blddensity 0.358
# vertohor 0.3004
# grasscover 0.2695
# treecover 0.1289
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 76
# bldheight 76.8867
# blddensity 0.358
# vertohor 0.3004
# grasscover 0.0273
# treecover 0.4336
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 77
# bldheight 76.8867
# blddensity 0.1354
# vertohor 0.9191
# grasscover 0.2695
# treecover 0.4336
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 78
# bldheight 76.8867
# blddensity 0.5955
# vertohor 0.9754
# grasscover 0.0195
# treecover 0.3789
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 79
# bldheight 76.8867
# blddensity 0.551
# vertohor 0.9191
# grasscover 0.0898
# treecover 0.3164
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 80
# bldheight 76.8867
# blddensity 0.1799
# vertohor 0.2441
# grasscover 0.582
# treecover 0.0664
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 81
# bldheight 76.8867
# blddensity 0.0611
# vertohor 0.8066
# grasscover 0.4648
# treecover 0.2461
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 82
# bldheight 76.8867
# blddensity 0.5361
# vertohor 0.3566
# grasscover 0.207
# treecover 0.1914
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 83
# bldheight 76.8867
# blddensity 0.2986
# vertohor 0.5816
# grasscover 0.2148
# treecover 0.4414
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 84
# bldheight 76.8867
# blddensity 0.2986
# vertohor 0.5816
# grasscover 0.2148
# treecover 0.4414
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 85
# bldheight 76.8867
# blddensity 0.1947
# vertohor 0.5816
# grasscover 0.2148
# treecover 0.4414
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 86
# bldheight 76.8867
# blddensity 0.2986
# vertohor 0.8629
# grasscover 0.2148
# treecover 0.4414
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 87
# bldheight 76.8867
# blddensity 0.3283
# vertohor 0.891
# grasscover 0.3086
# treecover 0.0352
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 88
# bldheight 76.8867
# blddensity 0.3283
# vertohor 0.891
# grasscover 0.3086
# treecover 0.0352
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 89
# bldheight 76.8867
# blddensity 0.3283
# vertohor 0.8348
# grasscover 0.3086
# treecover 0.0352
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 90
# bldheight 76.8867
# blddensity 0.0908
# vertohor 0.666
# grasscover 0.0586
# treecover 0.7852
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 91
# bldheight 76.8867
# blddensity 0.0908
# vertohor 0.666
# grasscover 0.0586
# treecover 0.7852
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 92
# bldheight 76.8867
# blddensity 0.0908
# vertohor 0.1598
# grasscover 0.0586
# treecover 0.7852
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 93
# bldheight 76.8867
# blddensity 0.0908
# vertohor 0.666
# grasscover 0.1133
# treecover 0.7852
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 94
# bldheight 76.8867
# blddensity 0.0908
# vertohor 0.666
# grasscover 0.0586
# treecover 0.1523
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 95
# bldheight 76.8867
# blddensity 0.2096
# vertohor 0.3285
# grasscover 0.2383
# treecover 0.4102
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 96
# bldheight 76.8867
# blddensity 0.4025
# vertohor 0.5535
# grasscover 0.4336
# treecover 0.1602
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 97
# bldheight 76.8867
# blddensity 0.4025
# vertohor 0.4973
# grasscover 0.4883
# treecover 0.0273
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 98
# bldheight 76.8867
# blddensity 0.1502
# vertohor 0.1598
# grasscover 0.2461
# treecover 0.5977
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 99
# bldheight 76.8867
# blddensity 0.1502
# vertohor 0.1598
# grasscover 0.2461
# treecover 0.5977
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 100
# bldheight 76.8867
# blddensity 0.1502
# vertohor 0.216
# grasscover 0.2461
# treecover 0.5977
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 101
# bldheight 76.8867
# blddensity 0.1502
# vertohor 0.1598
# grasscover 0.1758
# treecover 0.5977
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 102
# bldheight 76.8867
# blddensity 0.1057
# vertohor 0.6098
# grasscover 0.7461
# treecover 0.0977
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 103
# bldheight 76.8867
# blddensity 0.1057
# vertohor 0.666
# grasscover 0.6758
# treecover 0.2148
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 104
# bldheight 76.8867
# blddensity 0.2689
# vertohor 0.9473
# grasscover 0.0508
# treecover 0.2227
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 105
# bldheight 76.8867
# blddensity 0.2541
# vertohor 0.4832
# grasscover 0.168
# treecover 0.0117
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# ###
# RUN 106
# bldheight 76.8867
# blddensity 0.7291
# vertohor 0.9332
# grasscover 0.0977
# treecover 0.1445
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1

# %%
# Perform analysis
Si = sobol.analyze(problem, Y, print_to_console=True)

print("{:28s} {:>5s} {:>5s} {:>12s}".format("Name", "1st", "Total", "Mean of Input"))
for name, s1, st, mean in zip(problem['names'], Si['S1'], Si['ST'], param.mean(axis=0)):
    print("{:28s} {:=5.2f} {:=5.2f} ({:=12.2f})".format(name, s1, st, mean)) 



print("************")

columns = []
bounds = []

for col in problem['names']:
    columns.append(col)
    
for b in problem['bounds']:
        bounds.append(b) 


rows = []
data =  []    
 
cnt=0
for key, value in Si.items():
    rows.append(key)
    data.append(value.round(3))
    cnt+=1
    if cnt > 3:
        break
        

total_Si, first_Si, second_Si = Si.to_df()
print(first_Si)
print(second_Si)
print(total_Si)


# https://github.com/SALib/SALib/issues/206
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[477], line 2
#       1 # Perform analysis
# ----> 2 Si = sobol.analyze(problem, Y, print_to_console=True)
#       4 print("{:28s} {:>5s} {:>5s} {:>12s}".format("Name", "1st", "Total", "Mean of Input"))
#       5 for name, s1, st, mean in zip(problem['names'], Si['S1'], Si['ST'], param.mean(axis=0)):
#
# File ~/anaconda3/envs/datascience/lib/python3.9/site-packages/SALib/analyze/sobol.py:132, in analyze(problem, Y, calc_second_order, num_resamples, conf_level, print_to_console, parallel, n_processors, keep_resamples, seed)
#     130     N = int(Y.size / (D + 2))
#     131 else:
# --> 132     raise RuntimeError(
#     133         """
#     134     Incorrect number of samples in model output file.
#     135     Confirm that calc_second_order matches option used during sampling."""
#     136     )
#     138 if not 0 < conf_level < 1:
#     139     raise RuntimeError("Confidence level must be between 0-1.")
#
# RuntimeError:
#         Incorrect number of samples in model output file.
#         Confirm that calc_second_order matches option used during sampling.

# %%
pd.DataFrame(Y)
# Out:
#             0
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 1195      NaN
# 1196      NaN
# 1197      NaN
# 1198  2.51122
# 1199      NaN
#
# [1200 rows x 1 columns]

# %%
Si
# Out:
# {'S1': array([nan, nan, nan, nan, nan]),
#  'S1_conf': array([nan, nan, nan, nan, nan]),
#  'ST': array([nan, nan, nan, nan, nan]),
#  'ST_conf': array([nan, nan, nan, nan, nan]),
#  'S2': array([[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]]),
#  'S2_conf': array([[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]])}

# %%
Si_filter = {k:Si[k] for k in ['ST','ST_conf','S1','S1_conf']}
Si_df = pd.DataFrame(Si_filter, index=problem['names'])
Si_df
# Out:
#             ST  ST_conf  S1  S1_conf
# bldheight  NaN      NaN NaN      NaN
# blddensity NaN      NaN NaN      NaN
# vertohor   NaN      NaN NaN      NaN
# grasscover NaN      NaN NaN      NaN
# treecover  NaN      NaN NaN      NaN

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
fig, ax = plt.subplots(1)

indices = Si_df[['S1','ST']]
err = Si_df[['S1_conf','ST_conf']]

indices.plot.bar(yerr=err.values.T,ax=ax)
fig.set_size_inches(8,4)

plt.show()

# Save figure
name = "bar_plot_S1_ST"
#fig.savefig(name + '.pdf', bbox_inches='tight', pad_inches=0.0)

# %%
import itertools
from math import pi
import seaborn as sns
sns.set_style('whitegrid')
from math import pi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def normalize(x, xmin, xmax):
    return (x-xmin)/(xmax-xmin)


def plot_circles(ax, locs, names, max_s, stats, smax, smin, fc, ec, lw,
                 zorder):
    s = np.asarray([stats[name] for name in names])
    s = 0.01 + max_s * np.sqrt(normalize(s, smin, smax))

    fill = True
    for loc, name, si in zip(locs, names, s):
        if fc=='w':
            fill=False
        else:
            ec='none'

        x = np.cos(loc)
        y = np.sin(loc)

        circle = plt.Circle((x,y), radius=si, ec=ec, fc=fc, transform=ax.transData._b,
                            zorder=zorder, lw=lw, fill=True)
        ax.add_artist(circle)


def filter(sobol_indices, names, locs, criterion, threshold):
    if criterion in ['ST', 'S1', 'S2']:
        data = sobol_indices[criterion]
        data = np.abs(data)
        data = data.flatten() # flatten in case of S2
        # TODO:: remove nans

        filtered = ([(name, locs[i]) for i, name in enumerate(names) if
                     data[i]>threshold])
        filtered_names, filtered_locs = zip(*filtered)
    elif criterion in ['ST_conf', 'S1_conf', 'S2_conf']:
        raise NotImplementedError
    else:
        raise ValueError('unknown value for criterion')

    return filtered_names, filtered_locs


def plot_sobol_indices(problem, sobol_indices, criterion='ST', threshold=0.01):
    '''plot sobol indices on a radial plot

    Parameters
    ----------
    sobol_indices : dict
                    the return from SAlib
    criterion : {'ST', 'S1', 'S2', 'ST_conf', 'S1_conf', 'S2_conf'}, optional
    threshold : float
                only visualize variables with criterion larger than cutoff

    '''
    max_linewidth_s2 = 15#25*1.8
    max_s_radius = 0.3

    # prepare data
    # use the absolute values of all the indices
    #sobol_indices = {key:np.abs(stats) for key, stats in sobol_indices.items()}

    # dataframe with ST and S1
    sobol_stats = {key:sobol_indices[key] for key in ['ST', 'S1']}
    sobol_stats = pd.DataFrame(sobol_stats, index=problem['names'])

    smax = sobol_stats.max().max()
    smin = sobol_stats.min().min()

    # dataframe with s2
    s2 = pd.DataFrame(sobol_indices['S2'], index=problem['names'],
                      columns=problem['names'])
    s2[s2<0.0]=0. #Set negative values to 0 (artifact from small sample sizes)
    s2max = s2.max().max()
    s2min = s2.min().min()

    names = problem['names']
    n = len(names)
   
    ticklocs = np.linspace(0, 2*pi, n+1)
    locs = ticklocs[0:-1]


    filtered_names, filtered_locs = filter(sobol_indices, names, locs,
                                           criterion, threshold)

    # setup figure
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)
    ax.grid(False)
    ax.spines['polar'].set_visible(False)
   
    ax.set_xticks(ticklocs[0:len(names)])

    ax.set_xticklabels(names)
    ax.set_yticklabels([])
    
    ax.set_ylim(top=1.4)
    legend(ax)

    # plot ST
    plot_circles(ax, filtered_locs, filtered_names, max_s_radius,
                 sobol_stats['ST'], smax, smin, 'w', 'k', 1, 9)

    # plot S1
    plot_circles(ax, filtered_locs, filtered_names, max_s_radius,
                 sobol_stats['S1'], smax, smin, 'k', 'k', 1, 10)

    # plot S2
    for name1, name2 in itertools.combinations(zip(filtered_names, filtered_locs), 2):
        name1, loc1 = name1
        name2, loc2 = name2

        weight = s2.loc[name1, name2]
        lw = 0.5+max_linewidth_s2*normalize(weight, s2min, s2max)
        ax.plot([loc1, loc2], [1,1], c='darkgray', lw=lw, zorder=1)

    return fig


from matplotlib.legend_handler import HandlerPatch
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize, trans):
        center = 0.5 * width - 0.5 * xdescent, 0.5 * height - 0.5 * ydescent
        p = plt.Circle(xy=center, radius=orig_handle.radius)
        self.update_prop(p, orig_handle, legend)
        p.set_transform(trans)
        return [p]

def legend(ax):
    some_identifiers = [plt.Circle((0,0), radius=5, color='k', fill=False, lw=1),
                        plt.Circle((0,0), radius=5, color='k', fill=True),
                        plt.Line2D([0,0.5], [0,0.5], lw=8, color='darkgray')]
    ax.legend(some_identifiers, ['ST', 'S1', 'S2'],
              loc=(1,0.75), borderaxespad=0.1, mode='expand',
              handler_map={plt.Circle: HandlerCircle()})

# %%
# %matplotlib inline

fig = plot_sobol_indices(problem,Si, criterion='ST', threshold=0.005)
fig.set_size_inches(7,7)
plt.show()
