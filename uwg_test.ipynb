# %%
from epw import epw



a=epw()
b=epw()
epw_path_a = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"
epw_path_b = "resources/USA_GA_Atlanta.722190_TMY2.epw"
a.read(epw_path_a)
b.read(epw_path_b)

# Remove extra day in leap year
GT = a.dataframe.drop([i+1417 for i in range(24)])


display(GT)
# Out:
#       Year  Month  Day  Hour  Minute    Data Source and Uncertainty Flags  \
# 0     2020      1    1     1       0  'Created with NREL PSM3 input data'
# 1     2020      1    1     2       0  'Created with NREL PSM3 input data'
# 2     2020      1    1     3       0  'Created with NREL PSM3 input data'
# 3     2020      1    1     4       0  'Created with NREL PSM3 input data'
# 4     2020      1    1     5       0  'Created with NREL PSM3 input data'
# ...    ...    ...  ...   ...     ...                                  ...
# 8779  2020     12   31    20       0  'Created with NREL PSM3 input data'
# 8780  2020     12   31    21       0  'Created with NREL PSM3 input data'
# 8781  2020     12   31    22       0  'Created with NREL PSM3 input data'
# 8782  2020     12   31    23       0  'Created with NREL PSM3 input data'
# 8783  2020     12   31    24       0  'Created with NREL PSM3 input data'
#
#       Dry Bulb Temperature  Dew Point Temperature  Relative Humidity  \
# 0                      1.7                    1.7              99.88
# 1                      1.1                    1.1             100.00
# 2                      0.7                    0.7             100.00
# 3                      0.3                    0.3             100.00
# 4                      0.0                    0.0             100.00
# ...                    ...                    ...                ...
# 8779                   3.8                    2.1              88.40
# 8780                   3.2                    2.0              91.90
# 8781                   2.8                    2.0              94.39
# 8782                   2.4                    1.9              96.81
# 8783                   2.1                    1.8              98.04
#
#       Atmospheric Station Pressure  ...  Ceiling Height  \
# 0                            98300  ...           99999
# 1                            98300  ...           99999
# 2                            98300  ...           99999
# 3                            98300  ...           99999
# 4                            98300  ...           99999
# ...                            ...  ...             ...
# 8779                         98200  ...           99999
# 8780                         98200  ...           99999
# 8781                         98300  ...           99999
# 8782                         98300  ...           99999
# 8783                         98300  ...           99999
#
#       Present Weather Observation  Present Weather Codes  Precipitable Water  \
# 0                             NaN                    NaN                 0.8
# 1                             NaN                    NaN                 0.8
# 2                             NaN                    NaN                 0.8
# 3                             NaN                    NaN                 0.8
# 4                             NaN                    NaN                 0.9
# ...                           ...                    ...                 ...
# 8779                          NaN                    NaN                 0.7
# 8780                          NaN                    NaN                 0.7
# 8781                          NaN                    NaN                 0.7
# 8782                          NaN                    NaN                 0.7
# 8783                          NaN                    NaN                 0.8
#
#       Aerosol Optical Depth  Snow Depth  Days Since Last Snowfall  Albedo  \
# 0                     0.999         999                        99    0.11
# 1                     0.999         999                        99    0.11
# 2                     0.999         999                        99    0.11
# 3                     0.999         999                        99    0.11
# 4                     0.999         999                        99    0.11
# ...                     ...         ...                       ...     ...
# 8779                  0.999         999                        99    0.11
# 8780                  0.999         999                        99    0.11
# 8781                  0.999         999                        99    0.11
# 8782                  0.999         999                        99    0.11
# 8783                  0.999         999                        99    0.11
#
#       Liquid Precipitation Depth  Liquid Precipitation Quantity
# 0                            999                             99
# 1                            999                             99
# 2                            999                             99
# 3                            999                             99
# 4                            999                             99
# ...                          ...                            ...
# 8779                         999                             99
# 8780                         999                             99
# 8781                         999                             99
# 8782                         999                             99
# 8783                         999                             99
#
# [8760 rows x 35 columns]

# %%
vars = ['Year', 'Month', 'Day', 'Hour', 'Minute',
       'Data Source and Uncertainty Flags', 'Dry Bulb Temperature',
       'Dew Point Temperature', 'Relative Humidity',
       'Atmospheric Station Pressure', 'Extraterrestrial Horizontal Radiation',
       'Extraterrestrial Direct Normal Radiation',
       'Horizontal Infrared Radiation Intensity',
       'Global Horizontal Radiation', 'Direct Normal Radiation',
       'Diffuse Horizontal Radiation', 'Global Horizontal Illuminance',
       'Direct Normal Illuminance', 'Diffuse Horizontal Illuminance',
       'Zenith Luminance', 'Wind Direction', 'Wind Speed', 'Total Sky Cover',
       'Opaque Sky Cover (used if Horizontal IR Intensity missing)',
       'Visibility', 'Ceiling Height', 'Present Weather Observation',
       'Present Weather Codes', 'Precipitable Water', 'Aerosol Optical Depth',
       'Snow Depth', 'Days Since Last Snowfall', 'Albedo',
       'Liquid Precipitation Depth', 'Liquid Precipitation Quantity']


idx = 16
print(vars[idx])


dfa = a.dataframe
dfa[vars[idx]].plot(label= "GT", legend=True)

dfb = b.dataframe
dfb[vars[idx]].plot(label= "Airport", legend=True)

# We don't have Global Horizontal Illuminance data from NREL; this might be an issue
# Out:
# Global Horizontal Illuminance
# <Axes: >

# %%
from epw import epw

a=epw()

epw_path_a = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"

a.read(epw_path_a)




a.dataframe['Atmospheric Station Pressure'] = a.dataframe['Atmospheric Station Pressure']*100

display(a.dataframe)

a.write("resources/GT_33.77463936796479_-84.39704008595767_2020_edit.epw")
# Out:
#       Year  Month  Day  Hour  Minute    Data Source and Uncertainty Flags  \
# 0     2020      1    1     1       0  'Created with NREL PSM3 input data'
# 1     2020      1    1     2       0  'Created with NREL PSM3 input data'
# 2     2020      1    1     3       0  'Created with NREL PSM3 input data'
# 3     2020      1    1     4       0  'Created with NREL PSM3 input data'
# 4     2020      1    1     5       0  'Created with NREL PSM3 input data'
# ...    ...    ...  ...   ...     ...                                  ...
# 8779  2020     12   31    20       0  'Created with NREL PSM3 input data'
# 8780  2020     12   31    21       0  'Created with NREL PSM3 input data'
# 8781  2020     12   31    22       0  'Created with NREL PSM3 input data'
# 8782  2020     12   31    23       0  'Created with NREL PSM3 input data'
# 8783  2020     12   31    24       0  'Created with NREL PSM3 input data'
#
#       Dry Bulb Temperature  Dew Point Temperature  Relative Humidity  \
# 0                      1.7                    1.7              99.88
# 1                      1.1                    1.1             100.00
# 2                      0.7                    0.7             100.00
# 3                      0.3                    0.3             100.00
# 4                      0.0                    0.0             100.00
# ...                    ...                    ...                ...
# 8779                   3.8                    2.1              88.40
# 8780                   3.2                    2.0              91.90
# 8781                   2.8                    2.0              94.39
# 8782                   2.4                    1.9              96.81
# 8783                   2.1                    1.8              98.04
#
#       Atmospheric Station Pressure  ...  Ceiling Height  \
# 0                          9830000  ...           99999
# 1                          9830000  ...           99999
# 2                          9830000  ...           99999
# 3                          9830000  ...           99999
# 4                          9830000  ...           99999
# ...                            ...  ...             ...
# 8779                       9820000  ...           99999
# 8780                       9820000  ...           99999
# 8781                       9830000  ...           99999
# 8782                       9830000  ...           99999
# 8783                       9830000  ...           99999
#
#       Present Weather Observation  Present Weather Codes  Precipitable Water  \
# 0                             NaN                    NaN                 0.8
# 1                             NaN                    NaN                 0.8
# 2                             NaN                    NaN                 0.8
# 3                             NaN                    NaN                 0.8
# 4                             NaN                    NaN                 0.9
# ...                           ...                    ...                 ...
# 8779                          NaN                    NaN                 0.7
# 8780                          NaN                    NaN                 0.7
# 8781                          NaN                    NaN                 0.7
# 8782                          NaN                    NaN                 0.7
# 8783                          NaN                    NaN                 0.8
#
#       Aerosol Optical Depth  Snow Depth  Days Since Last Snowfall  Albedo  \
# 0                     0.999         999                        99    0.11
# 1                     0.999         999                        99    0.11
# 2                     0.999         999                        99    0.11
# 3                     0.999         999                        99    0.11
# 4                     0.999         999                        99    0.11
# ...                     ...         ...                       ...     ...
# 8779                  0.999         999                        99    0.11
# 8780                  0.999         999                        99    0.11
# 8781                  0.999         999                        99    0.11
# 8782                  0.999         999                        99    0.11
# 8783                  0.999         999                        99    0.11
#
#       Liquid Precipitation Depth  Liquid Precipitation Quantity
# 0                            999                             99
# 1                            999                             99
# 2                            999                             99
# 3                            999                             99
# 4                            999                             99
# ...                          ...                            ...
# 8779                         999                             99
# 8780                         999                             99
# 8781                         999                             99
# 8782                         999                             99
# 8783                         999                             99
#
# [8784 rows x 35 columns]

# %%
from uwg import UWG
import numpy as np
import math

# Define the .epw, .uwg paths to create an uwg object.
epw_path = "resources/GT_33.77463936796479_-84.39704008595767_2020.epw"
#epw_path = "resources/USA_GA_Atlanta.722190_TMY2.epw" # available in resources directory.

# path for Atlanta Airport EPW: Sp24-Microclimate/resources/USA_GA_Atlanta.722190_TMY2.epw
# path for GT Campus EPW: Sp24-Microclimate/resources/GT_33.77463936796479_-84.39704008595767_2020.epw

# Initialize the UWG model by passing parameters as arguments, or relying on defaults
model = UWG.from_param_args(epw_path=epw_path, bldheight=10, blddensity=0.5,
                            vertohor=0.8, grasscover=0.1, treecover=0.1, zone='7') # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

model.generate()
model.simulate()

# Write the simulation result to a file.
model.write_epw()
# Out:
# Simulating new temperature and humidity values for 31 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10
# Simulating Day 11
# Simulating Day 12
# Simulating Day 13
# Simulating Day 14
# Simulating Day 15
# Simulating Day 16
# Simulating Day 17
# Simulating Day 18
# Simulating Day 19
# Simulating Day 20
# Simulating Day 21
# Simulating Day 22
# Simulating Day 23
# Simulating Day 24
# Simulating Day 25
# Simulating Day 26
# Simulating Day 27
# Simulating Day 28
# Simulating Day 29
# Simulating Day 30
# Simulating Day 31
# New climate file is generated at resources\GT_33.77463936796479_-84.39704008595767_2020_UWG.epw.

# %%
def calculate_degree_days(hourly_temps, base_temp=18.3):
    """
    Calculate Heating Degree Days (HDD) and Cooling Degree Days (CDD) from hourly temperature data.

    Parameters:
    - hourly_temps: list of 8760 hourly temperature values in degrees Fahrenheit.
    - base_temp: base temperature for calculating HDD and CDD, default is 18.3°C.

    Returns:
    - A tuple containing total HDD and CDD.
    """
    # Ensure the input list has 8760 values (24 hours * 365 days)
    if len(hourly_temps) != 8760:
        raise ValueError("Input list must contain 8760 hourly temperature values.")

    # Calculate daily average temperatures
    daily_avgs = [sum(hourly_temps[i:i+24])/24 for i in range(0, 8760, 24)]
    # Calculate HDD and CDD

    hdd = sum(base_temp - temp for temp in daily_avgs if temp < base_temp)
    cdd = sum(temp - base_temp for temp in daily_avgs if temp > base_temp)

    return hdd, cdd


# Example hourly temperature data (replace this with your actual data)
hourly_temps = [60] * 8760  # Example data, replace with your real temperatures

# Calculate HDD and CDD
hdd, cdd = calculate_degree_days(hourly_temps)
print(f"Heating Degree Days: {hdd}, Cooling Degree Days: {cdd}")
# Out:
# Heating Degree Days: 0, Cooling Degree Days: 15220.500000000098

# %%
model = UWG.from_param_args(epw_path=epw_path, bldheight=10, blddensity=0.5, vertohor=0.8, grasscover=0.1, treecover=0.1, zone='7', nday= 10) # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

model.generate()
model.simulate()
# Out:
# Simulating new temperature and humidity values for 10 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10

# %%
np.array([1,2,3]) - np.array([3,4,5])
# Out:
# array([-2, -2, -2])

# %%
from numba import jit
import numpy as np


@jit(nopython=True)
def rmse(y1, y2):
    return np.linalg.norm(y1 - y2) / np.sqrt(len(y1))


def get_SA_metric(epw_path_before_sim, simulated_UWG_model, days_simulated):
    e=epw()
    e.read(epw_path_before_sim)
    epw_df = e.dataframe
    if len(e.dataframe) > 8760:
        epw_df = e.dataframe.drop([i+1417 for i in range(24)])

    simulated_UWG_model.UCMData[0].canTemp-273.15 # This is the canyon air temperature it seems
    ambTemp = [model.UCMData[hour].canTemp-273.15  for hour in range(days_simulated*24) ]

    return rmse(np.array(epw_df['Dry Bulb Temperature'].values[:(24*days_simulated)]), np.array(ambTemp))

get_SA_metric(epw_path_a, model, 10)
# Out:
# 2.2393044445487127

# %%
'''

from SALib.sample import sobol
from SALib.analyze import sobol
from SALib.test_functions import Ishigami
from SALib.sample import morris as ms
from SALib.analyze import morris as ma
from SALib.plotting import morris as mp
from SALib.sample import saltelli
import pandas as pd

problem = {
    'num_vars': 14,  # Number of variables

    'names': [
        # Urban characteristics
        'bldheight', 'blddensity', 'vertohor', 'charlength',
        'albroad', 'croad', 'sensanth',
        # Vegetation parameters
        'treecover', 'vegstart', 'vegend', 'albveg',
        # Simulation parameters
        'nday',
        # Urban climate parameters
        'h_ubl1', 'h_ubl2'
    ],

    'bounds': [
    # Urban characteristics
    [3, 100],   # bldheight - avg building height
    [0.05, 1],  # blddensity - urban area building plan density
    [0.1, 1],   # vertohor - urban area vertical to horizontal ratio
    [0, 1],     # charlength - dimension of a square that encompasses the whole neighborhood [aka. characteristic length] (m)
    [0, 1],     # albroad - road albedo
    [0, 1600000],  # croad - road volumetric heat capacity (J/m^3 K)
    [0, 20],    # sensanth - non-building sensible heat at street level [aka. heat from cars, pedestrians, street cooking, etc. ] (W/m^2)
    
    # Vegetation parameters
    [0, 1],     # treecover - Fraction of the urban ground covered in trees (0-1)
    [1, 12],    # vegstart - The month in which vegetation starts to evapotranspire (leaves are out)
    [1, 12],    # vegend - The month in which vegetation stops evapotranspiring (leaves fall)
    [0, 1],     # albveg - vegetation albedo

    # Simulation parameters
    [1, 365],   # nday
    
    # Urban climate parameters
    [0, 2000],  # h_ubl1 - urban boundary layer during the day
    [0, 200],   # h_ubl2 - urban boundary layer during the night
    ],

'groups': None
}

print("Number of variables:", problem['num_vars'])
print("Length of bounds:", len(problem['bounds']))

# We'll perform a Sobol Sensitivity Analysis below.
# Generate samples
param = saltelli.sample(problem, 100, calc_second_order=False)
pd.DataFrame(param, columns = problem['names'])
'''
# Out:
# '\n\nfrom SALib.sample import sobol\nfrom SALib.analyze import sobol\nfrom SALib.test_functions import Ishigami\nfrom SALib.sample import morris as ms\nfrom SALib.analyze import morris as ma\nfrom SALib.plotting import morris as mp\nfrom SALib.sample import saltelli\nimport pandas as pd\n\nproblem = {\n    \'num_vars\': 14,  # Number of variables\n\n    \'names\': [\n        # Urban characteristics\n        \'bldheight\', \'blddensity\', \'vertohor\', \'charlength\',\n        \'albroad\', \'croad\', \'sensanth\',\n        # Vegetation parameters\n        \'treecover\', \'vegstart\', \'vegend\', \'albveg\',\n        # Simulation parameters\n        \'nday\',\n        # Urban climate parameters\n        \'h_ubl1\', \'h_ubl2\'\n    ],\n\n    \'bounds\': [\n    # Urban characteristics\n    [3, 100],   # bldheight - avg building height\n    [0.05, 1],  # blddensity - urban area building plan density\n    [0.1, 1],   # vertohor - urban area vertical to horizontal ratio\n    [0, 1],     # charlength - dimension of a square that encompasses the whole neighborhood [aka. characteristic length] (m)\n    [0, 1],     # albroad - road albedo\n    [0, 1600000],  # croad - road volumetric heat capacity (J/m^3 K)\n    [0, 20],    # sensanth - non-building sensible heat at street level [aka. heat from cars, pedestrians, street cooking, etc. ] (W/m^2)\n    \n    # Vegetation parameters\n    [0, 1],     # treecover - Fraction of the urban ground covered in trees (0-1)\n    [1, 12],    # vegstart - The month in which vegetation starts to evapotranspire (leaves are out)\n    [1, 12],    # vegend - The month in which vegetation stops evapotranspiring (leaves fall)\n    [0, 1],     # albveg - vegetation albedo\n\n    # Simulation parameters\n    [1, 365],   # nday\n    \n    # Urban climate parameters\n    [0, 2000],  # h_ubl1 - urban boundary layer during the day\n    [0, 200],   # h_ubl2 - urban boundary layer during the night\n    ],\n\n\'groups\': None\n}\n\nprint("Number of variables:", problem[\'num_vars\'])\nprint("Length of bounds:", len(problem[\'bounds\']))\n\n# We\'ll perform a Sobol Sensitivity Analysis below.\n# Generate samples\nparam = saltelli.sample(problem, 100, calc_second_order=False)\npd.DataFrame(param, columns = problem[\'names\'])\n'

# %%
from SALib.sample import sobol
from SALib.analyze import sobol
from SALib.test_functions import Ishigami
from SALib.sample import morris as ms
from SALib.analyze import morris as ma
from SALib.plotting import morris as mp
from SALib.sample import saltelli
import pandas as pd

# Initialize the UWG model by passing parameters as arguments, or relying on defaults
#model = UWG.from_param_args(epw_path=epw_path, bldheight=10, blddensity=0.5,
#                            vertohor=0.8, grasscover=0.1, treecover=0.1, zone='7') # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

# Define the model inputs
test_problem = {
    'num_vars': 5,
    'names': ['bldheight', 'blddensity', 'vertohor', 'grasscover', 'treecover'],
    'bounds': [[3,100],
               [0.05, 1],
               [0.1, 1],
               [0, 1],
               [0, 1],
               ],
    # I don't want to group any of these variables together
    'groups': None
}


# We'll perform a Sobol Sensitivity Analysis below.
# Generate samples
param = saltelli.sample(test_problem, 100, calc_second_order=True)

#edit - changed calc_second_order to true

param[:, 1:4] = np.clip(param[:, 1:4], 0, 1)
param[:, 1:4] /= param[:, 1:4].sum(axis=1, keepdims=True)

pd.DataFrame(param, columns = test_problem['names'])
# Out:
# C:\Users\zeyuj\AppData\Local\Temp\ipykernel_15912\3339001454.py:31: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5. Please use `salib.sample.sobol`
#   param = saltelli.sample(test_problem, 100, calc_second_order=True)
# C:\Users\zeyuj\AppData\Roaming\Python\Python311\site-packages\SALib\sample\saltelli.py:109: UserWarning:
#         Convergence properties of the Sobol' sequence is only valid if
#         `N` (100) is equal to `2^n`.
#
#   warnings.warn(msg)
#       bldheight  blddensity  vertohor  grasscover  treecover
# 0      4.136719    0.396987  0.395077    0.207935   0.902344
# 1     68.550781    0.396987  0.395077    0.207935   0.902344
# 2      4.136719    0.610525  0.255173    0.134302   0.902344
# 3      4.136719    0.416055  0.366022    0.217923   0.902344
# 4      4.136719    0.437866  0.435759    0.126375   0.902344
# ...         ...         ...       ...         ...        ...
# 1195  46.574219    0.420999  0.522612    0.056389   0.511719
# 1196  46.574219    0.329437  0.607038    0.063524   0.511719
# 1197  46.574219    0.243543  0.435240    0.321217   0.511719
# 1198  46.574219    0.335577  0.599715    0.064708   0.144531
# 1199  46.574219    0.335577  0.599715    0.064708   0.511719
#
# [1200 rows x 5 columns]

# %%
# Randomize columns 1, 3, and 4 between 0.1 and 0.9
# let me know if we should do avg or interpolation instead
# felt that randomizing usable combinations would lead to less bias
rand_vals = np.random.uniform(0.1, 0.9, size=(param.shape[0], 3))
param[:, [1, 3, 4]] = rand_vals / rand_vals.sum(axis=1, keepdims=True)

df = pd.DataFrame(param, columns=test_problem['names'])
print(df)
# Out:
#       bldheight  blddensity  vertohor  grasscover  treecover
# 0      4.136719    0.134407  0.395077    0.542947   0.322646
# 1     68.550781    0.094193  0.395077    0.484701   0.421106
# 2      4.136719    0.380415  0.255173    0.204960   0.414625
# 3      4.136719    0.319390  0.366022    0.309020   0.371590
# 4      4.136719    0.378322  0.435759    0.427470   0.194208
# ...         ...         ...       ...         ...        ...
# 1195  46.574219    0.434766  0.522612    0.294695   0.270540
# 1196  46.574219    0.114831  0.607038    0.299542   0.585627
# 1197  46.574219    0.197217  0.435240    0.432933   0.369850
# 1198  46.574219    0.204567  0.599715    0.419560   0.375874
# 1199  46.574219    0.151348  0.599715    0.394706   0.453946
#
# [1200 rows x 5 columns]

# %%
# edit - testing the other types of parameters. only blddensity, grasscover, and treecover have the < 1 limit
# edit - this is where the error happened as we couldn't run the simulation and test the other parameters
# edit - once this is figure out, we can define the problem parameters with all of these
# edit - i've confirmed with Maryam who's contacted Sylvia about the usability of these parameters. We'll be able to get data for all of them

model = UWG.from_param_args(epw_path=epw_path, 
                            bldheight=80, # average building height
                            blddensity=0.60, # urban area building density (0 to 1)
                            vertohor=0.40, # urban area vertical to horizontal ratio
                            albroad=0.7, # road albedo (0 to 1)
                            croad=0.14, # road volumetric heat capacity (J/(m^3) K)
                            sensanth=17.2, # non-building sensible heat at street level [heat from cars, pedestrians, street cooking, etc]
                            grasscover= 0.10, # Fraction of the urban ground covered in grass/shrubs only (0 to 1)
                            treecover=0.20, # Fraction of the urban ground covered in trees (0 to 1)
                            vegstart=1, # The month in which vegetation starts to evapotranspire (leaves are out)
                            vegend=8, # The month in which vegetation stops evaporationspiring (leaves fall)
                            albveg=0.73, # Vegetation albedo
                            h_ubl1=1469, # ubl height - day (m)
                            h_ubl2=175, # ubl height - night (m)
                            zone='3A', # Zone - atlanta's zone within the backend is '3A'
                            nday=10) # number of days for simulation to be run
model.generate()
model.simulate()
# Out:
# Simulating new temperature and humidity values for 10 days from 1/1.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 23
#       6 model = UWG.from_param_args(epw_path=epw_path,
#       7                             bldheight=80, # average building height
#       8                             blddensity=0.60, # urban area building density (0 to 1)
#    (...)
#      20                             zone='3A', # Zone - atlanta's zone within the backend is '3A'
#      21                             nday=10) # number of days for simulation to be run
#      22 model.generate()
# ---> 23 model.simulate()
#
# File c:\Users\zeyuj\OneDrive\Desktop\Sp24-Microclimate\uwg\uwg.py:1345, in UWG.simulate(self)
#    1341 self.rural.infra = self.forc.infra - self.rural.emissivity * self.SIGMA * \
#    1342     self.rural.layerTemp[0] ** 4.    # Infrared radiation from rural road
#    1343 self.rural.SurfFlux(self.forc, self.geoParam, self.simTime,
#    1344                     self.forc.hum, self.forc.temp, self.forc.wind, 2., 0.)
# -> 1345 self.RSM.vdm(self.forc, self.rural, self.geoParam, self.simTime)
#    1347 # Calculate urban heat fluxes, update UCM & UBL
#    1348 self.UCM, self.UBL, self.BEM = urbflux(
#    1349     self.UCM, self.UBL, self.BEM, self.forc, self.geoParam, self.simTime,
#    1350     self.RSM)
#
# File c:\Users\zeyuj\OneDrive\Desktop\Sp24-Microclimate\uwg\RSMDef.py:226, in RSMDef.vdm(self, forc, rural, parameter, simTime)
#     223 self.ublPres = 0.
#     224 for iz in range(self.nzfor):
#     225     self.ublPres = (
# --> 226         self.ublPres + self.presProf[iz] * self.dz[iz] /
#     227         (self.z[self.nzref-1] + self.dz[self.nzref-1] / 2.))
#
# IndexError: list index out of range

# %%
i = 0

bldheight=float(df.iloc[i][0].round(4))
print("bldheight", bldheight)

blddensity=float(df.iloc[i][1].round(4))
print("blddensity", blddensity)

vertohor=float(df.iloc[i][2].round(4))
print("vertohor", vertohor)

grasscover=float(df.iloc[i][3].round(4))
print("grasscover", grasscover)

treecover=float(df.iloc[i][4].round(4))
print("treecover", treecover)



try:
    model1 = UWG.from_param_args(epw_path=epw_path, bldheight=bldheight, blddensity=blddensity, vertohor=vertohor, grasscover=grasscover, treecover=treecover, zone='7', nday= 10) # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

    model1.generate()
    model1.simulate()
except: 
    print("Some issue with combination of inputs --> make sure how to handle that correctly")
# Out:
# bldheight 4.1367
# blddensity 0.1344
# vertohor 0.3951
# grasscover 0.5429
# treecover 0.3226
# Simulating new temperature and humidity values for 10 days from 1/1.
# Simulating Day 1
# Simulating Day 2
# Simulating Day 3
# Simulating Day 4
# Simulating Day 5
# Simulating Day 6
# Simulating Day 7
# Simulating Day 8
# Simulating Day 9
# Simulating Day 10

# %%
sim_days = 1


# Run model (example)
Y = np.zeros([df.shape[0]])

for i, X in enumerate(df.iterrows()):

    print("bldheight", bldheight)

    blddensity=float(df.iloc[i][1].round(4))
    print("blddensity", blddensity)

    vertohor=float(df.iloc[i][2].round(4))
    print("vertohor", vertohor)

    grasscover=float(df.iloc[i][3].round(4))
    print("grasscover", grasscover)

    treecover=float(df.iloc[i][4].round(4))
    print("treecover", treecover)

    print("###")
    print("RUN", i)

    try:    

        model1 = UWG.from_param_args(epw_path=epw_path, bldheight=bldheight, blddensity=blddensity, vertohor=vertohor, grasscover=grasscover, treecover=treecover, zone='7', nday= sim_days) # Atlanta is in climate zone 7  --> https://www.walterreeves.com/landscaping/hardiness-zones-for-georgia/

        model1.generate()
        model1.simulate()
        
        Y[i] = get_SA_metric(epw_path_a, model1, sim_days)
    
    except: 
        Y[i] = None
        print("Some issue with inputs.")
# Out:
# bldheight 4.1367
# blddensity 0.1344
# vertohor 0.3951
# grasscover 0.5429
# treecover 0.3226
# ###
# RUN 0
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0942
# vertohor 0.3951
# grasscover 0.4847
# treecover 0.4211
# ###
# RUN 1
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3804
# vertohor 0.2552
# grasscover 0.205
# treecover 0.4146
# ###
# RUN 2
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3194
# vertohor 0.366
# grasscover 0.309
# treecover 0.3716
# ###
# RUN 3
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3783
# vertohor 0.4358
# grasscover 0.4275
# treecover 0.1942
# ###
# RUN 4
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.6188
# vertohor 0.3951
# grasscover 0.2596
# treecover 0.1216
# ###
# RUN 5
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1671
# vertohor 0.2479
# grasscover 0.2198
# treecover 0.6131
# ###
# RUN 6
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1469
# vertohor 0.4057
# grasscover 0.5015
# treecover 0.3516
# ###
# RUN 7
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4177
# vertohor 0.2715
# grasscover 0.4273
# treecover 0.155
# ###
# RUN 8
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2793
# vertohor 0.2325
# grasscover 0.3674
# treecover 0.3532
# ###
# RUN 9
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4143
# vertohor 0.2479
# grasscover 0.5214
# treecover 0.0643
# ###
# RUN 10
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3291
# vertohor 0.2479
# grasscover 0.4757
# treecover 0.1953
# ###
# RUN 11
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4249
# vertohor 0.3469
# grasscover 0.1695
# treecover 0.4057
# ###
# RUN 12
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3404
# vertohor 0.3469
# grasscover 0.3032
# treecover 0.3563
# ###
# RUN 13
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3574
# vertohor 0.4282
# grasscover 0.3851
# treecover 0.2576
# ###
# RUN 14
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0819
# vertohor 0.3349
# grasscover 0.2409
# treecover 0.6772
# ###
# RUN 15
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4257
# vertohor 0.3601
# grasscover 0.2995
# treecover 0.2748
# ###
# RUN 16
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3861
# vertohor 0.3469
# grasscover 0.3176
# treecover 0.2963
# ###
# RUN 17
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.292
# vertohor 0.4354
# grasscover 0.3607
# treecover 0.3472
# ###
# RUN 18
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3257
# vertohor 0.3479
# grasscover 0.548
# treecover 0.1264
# ###
# RUN 19
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1796
# vertohor 0.4485
# grasscover 0.6463
# treecover 0.1741
# ###
# RUN 20
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3323
# vertohor 0.4152
# grasscover 0.2734
# treecover 0.3944
# ###
# RUN 21
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2899
# vertohor 0.4354
# grasscover 0.2071
# treecover 0.503
# ###
# RUN 22
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1617
# vertohor 0.4354
# grasscover 0.4675
# treecover 0.3708
# ###
# RUN 23
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5653
# vertohor 0.1959
# grasscover 0.2901
# treecover 0.1445
# ###
# RUN 24
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1775
# vertohor 0.1959
# grasscover 0.6609
# treecover 0.1615
# ###
# RUN 25
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2381
# vertohor 0.1144
# grasscover 0.5775
# treecover 0.1844
# ###
# RUN 26
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4128
# vertohor 0.6364
# grasscover 0.3945
# treecover 0.1927
# ###
# RUN 27
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.217
# vertohor 0.1236
# grasscover 0.2962
# treecover 0.4868
# ###
# RUN 28
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3928
# vertohor 0.1959
# grasscover 0.4017
# treecover 0.2055
# ###
# RUN 29
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3709
# vertohor 0.4011
# grasscover 0.4789
# treecover 0.1503
# ###
# RUN 30
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2302
# vertohor 0.5033
# grasscover 0.3685
# treecover 0.4012
# ###
# RUN 31
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3967
# vertohor 0.0852
# grasscover 0.4966
# treecover 0.1067
# ###
# RUN 32
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3166
# vertohor 0.4813
# grasscover 0.2718
# treecover 0.4116
# ###
# RUN 33
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4755
# vertohor 0.4011
# grasscover 0.218
# treecover 0.3066
# ###
# RUN 34
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3608
# vertohor 0.4011
# grasscover 0.3323
# treecover 0.3069
# ###
# RUN 35
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1829
# vertohor 0.276
# grasscover 0.5514
# treecover 0.2657
# ###
# RUN 36
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1923
# vertohor 0.276
# grasscover 0.4397
# treecover 0.368
# ###
# RUN 37
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3907
# vertohor 0.3488
# grasscover 0.4208
# treecover 0.1884
# ###
# RUN 38
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3045
# vertohor 0.2614
# grasscover 0.5024
# treecover 0.1931
# ###
# RUN 39
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.545
# vertohor 0.3805
# grasscover 0.1305
# treecover 0.3245
# ###
# RUN 40
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3671
# vertohor 0.276
# grasscover 0.2625
# treecover 0.3704
# ###
# RUN 41
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4467
# vertohor 0.5158
# grasscover 0.3076
# treecover 0.2457
# ###
# RUN 42
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2014
# vertohor 0.3631
# grasscover 0.1275
# treecover 0.6711
# ###
# RUN 43
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5712
# vertohor 0.5343
# grasscover 0.1938
# treecover 0.235
# ###
# RUN 44
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4118
# vertohor 0.3321
# grasscover 0.1032
# treecover 0.485
# ###
# RUN 45
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4729
# vertohor 0.5158
# grasscover 0.2753
# treecover 0.2518
# ###
# RUN 46
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4593
# vertohor 0.5158
# grasscover 0.3558
# treecover 0.1849
# ###
# RUN 47
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4629
# vertohor 0.4656
# grasscover 0.3893
# treecover 0.1478
# ###
# RUN 48
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4085
# vertohor 0.4656
# grasscover 0.4912
# treecover 0.1003
# ###
# RUN 49
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4157
# vertohor 0.3714
# grasscover 0.4082
# treecover 0.1761
# ###
# RUN 50
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2461
# vertohor 0.454
# grasscover 0.3947
# treecover 0.3592
# ###
# RUN 51
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4487
# vertohor 0.4301
# grasscover 0.2276
# treecover 0.3237
# ###
# RUN 52
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1123
# vertohor 0.4656
# grasscover 0.776
# treecover 0.1117
# ###
# RUN 53
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4706
# vertohor 0.3379
# grasscover 0.4
# treecover 0.1295
# ###
# RUN 54
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2383
# vertohor 0.4187
# grasscover 0.1957
# treecover 0.5659
# ###
# RUN 55
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4769
# vertohor 0.3484
# grasscover 0.3277
# treecover 0.1954
# ###
# RUN 56
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3177
# vertohor 0.3606
# grasscover 0.5091
# treecover 0.1732
# ###
# RUN 57
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3278
# vertohor 0.3379
# grasscover 0.5062
# treecover 0.1659
# ###
# RUN 58
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1476
# vertohor 0.3379
# grasscover 0.4831
# treecover 0.3694
# ###
# RUN 59
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.529
# vertohor 0.3145
# grasscover 0.3457
# treecover 0.1253
# ###
# RUN 60
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.6094
# vertohor 0.3145
# grasscover 0.1402
# treecover 0.2504
# ###
# RUN 61
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5128
# vertohor 0.4455
# grasscover 0.2738
# treecover 0.2134
# ###
# RUN 62
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3677
# vertohor 0.2948
# grasscover 0.2628
# treecover 0.3695
# ###
# RUN 63
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4004
# vertohor 0.2837
# grasscover 0.2045
# treecover 0.3952
# ###
# RUN 64
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3892
# vertohor 0.3145
# grasscover 0.1845
# treecover 0.4263
# ###
# RUN 65
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2972
# vertohor 0.3644
# grasscover 0.2065
# treecover 0.4963
# ###
# RUN 66
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.145
# vertohor 0.2653
# grasscover 0.1941
# treecover 0.6609
# ###
# RUN 67
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3548
# vertohor 0.3862
# grasscover 0.0912
# treecover 0.5539
# ###
# RUN 68
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2635
# vertohor 0.4227
# grasscover 0.32
# treecover 0.4165
# ###
# RUN 69
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2935
# vertohor 0.3644
# grasscover 0.5228
# treecover 0.1837
# ###
# RUN 70
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3642
# vertohor 0.3644
# grasscover 0.1825
# treecover 0.4533
# ###
# RUN 71
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.6863
# vertohor 0.4003
# grasscover 0.2025
# treecover 0.1111
# ###
# RUN 72
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2986
# vertohor 0.4003
# grasscover 0.2745
# treecover 0.4269
# ###
# RUN 73
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4719
# vertohor 0.3107
# grasscover 0.1609
# treecover 0.3672
# ###
# RUN 74
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2274
# vertohor 0.1659
# grasscover 0.4419
# treecover 0.3307
# ###
# RUN 75
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.309
# vertohor 0.4952
# grasscover 0.389
# treecover 0.302
# ###
# RUN 76
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2653
# vertohor 0.4003
# grasscover 0.2637
# treecover 0.471
# ###
# RUN 77
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0777
# vertohor 0.1463
# grasscover 0.4729
# treecover 0.4494
# ###
# RUN 78
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.54
# vertohor 0.2263
# grasscover 0.2532
# treecover 0.2067
# ###
# RUN 79
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2785
# vertohor 0.3651
# grasscover 0.124
# treecover 0.5975
# ###
# RUN 80
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4845
# vertohor 0.1185
# grasscover 0.4283
# treecover 0.0871
# ###
# RUN 81
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1647
# vertohor 0.1463
# grasscover 0.2138
# treecover 0.6214
# ###
# RUN 82
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5853
# vertohor 0.1463
# grasscover 0.2037
# treecover 0.2109
# ###
# RUN 83
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4743
# vertohor 0.1967
# grasscover 0.3939
# treecover 0.1318
# ###
# RUN 84
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5255
# vertohor 0.1967
# grasscover 0.3712
# treecover 0.1033
# ###
# RUN 85
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4844
# vertohor 0.3021
# grasscover 0.3915
# treecover 0.1241
# ###
# RUN 86
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4499
# vertohor 0.3912
# grasscover 0.2807
# treecover 0.2695
# ###
# RUN 87
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.098
# vertohor 0.1294
# grasscover 0.7722
# treecover 0.1298
# ###
# RUN 88
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4572
# vertohor 0.1967
# grasscover 0.3168
# treecover 0.226
# ###
# RUN 89
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0937
# vertohor 0.3462
# grasscover 0.3323
# treecover 0.574
# ###
# RUN 90
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3483
# vertohor 0.2806
# grasscover 0.0718
# treecover 0.5799
# ###
# RUN 91
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2723
# vertohor 0.168
# grasscover 0.4952
# treecover 0.2325
# ###
# RUN 92
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4102
# vertohor 0.5318
# grasscover 0.1296
# treecover 0.4602
# ###
# RUN 93
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4765
# vertohor 0.3462
# grasscover 0.4128
# treecover 0.1108
# ###
# RUN 94
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5128
# vertohor 0.3462
# grasscover 0.3642
# treecover 0.123
# ###
# RUN 95
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2492
# vertohor 0.7014
# grasscover 0.3783
# treecover 0.3724
# ###
# RUN 96
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1996
# vertohor 0.7014
# grasscover 0.4311
# treecover 0.3693
# ###
# RUN 97
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1126
# vertohor 0.4447
# grasscover 0.5512
# treecover 0.3362
# ###
# RUN 98
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2831
# vertohor 0.7196
# grasscover 0.5418
# treecover 0.175
# ###
# RUN 99
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.467
# vertohor 0.4343
# grasscover 0.2222
# treecover 0.3108
# ###
# RUN 100
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3165
# vertohor 0.7014
# grasscover 0.2784
# treecover 0.4051
# ###
# RUN 101
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3746
# vertohor 0.3396
# grasscover 0.3218
# treecover 0.3037
# ###
# RUN 102
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3563
# vertohor 0.4562
# grasscover 0.2187
# treecover 0.425
# ###
# RUN 103
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.326
# vertohor 0.3199
# grasscover 0.4276
# treecover 0.2463
# ###
# RUN 104
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2631
# vertohor 0.4667
# grasscover 0.3609
# treecover 0.376
# ###
# RUN 105
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2793
# vertohor 0.3396
# grasscover 0.5804
# treecover 0.1403
# ###
# RUN 106
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3243
# vertohor 0.3396
# grasscover 0.1675
# treecover 0.5083
# ###
# RUN 107
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1682
# vertohor 0.1916
# grasscover 0.3357
# treecover 0.4961
# ###
# RUN 108
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1026
# vertohor 0.1916
# grasscover 0.3743
# treecover 0.5231
# ###
# RUN 109
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3707
# vertohor 0.2405
# grasscover 0.553
# treecover 0.0763
# ###
# RUN 110
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3439
# vertohor 0.2255
# grasscover 0.1958
# treecover 0.4603
# ###
# RUN 111
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3487
# vertohor 0.2423
# grasscover 0.5076
# treecover 0.1437
# ###
# RUN 112
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3407
# vertohor 0.1916
# grasscover 0.263
# treecover 0.3963
# ###
# RUN 113
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1344
# vertohor 0.373
# grasscover 0.7084
# treecover 0.1572
# ###
# RUN 114
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4253
# vertohor 0.282
# grasscover 0.0782
# treecover 0.4964
# ###
# RUN 115
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5919
# vertohor 0.3262
# grasscover 0.1288
# treecover 0.2793
# ###
# RUN 116
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1979
# vertohor 0.2801
# grasscover 0.5828
# treecover 0.2193
# ###
# RUN 117
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4557
# vertohor 0.373
# grasscover 0.2333
# treecover 0.311
# ###
# RUN 118
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4314
# vertohor 0.373
# grasscover 0.3792
# treecover 0.1894
# ###
# RUN 119
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2514
# vertohor 0.7602
# grasscover 0.345
# treecover 0.4036
# ###
# RUN 120
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2621
# vertohor 0.7602
# grasscover 0.1607
# treecover 0.5772
# ###
# RUN 121
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3151
# vertohor 0.5128
# grasscover 0.2066
# treecover 0.4783
# ###
# RUN 122
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2796
# vertohor 0.3301
# grasscover 0.308
# treecover 0.4124
# ###
# RUN 123
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2392
# vertohor 0.6745
# grasscover 0.4639
# treecover 0.2969
# ###
# RUN 124
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2343
# vertohor 0.7602
# grasscover 0.333
# treecover 0.4327
# ###
# RUN 125
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4387
# vertohor 0.1222
# grasscover 0.0794
# treecover 0.4819
# ###
# RUN 126
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3346
# vertohor 0.2437
# grasscover 0.3285
# treecover 0.3369
# ###
# RUN 127
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4629
# vertohor 0.4723
# grasscover 0.4564
# treecover 0.0807
# ###
# RUN 128
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.6593
# vertohor 0.1406
# grasscover 0.1252
# treecover 0.2155
# ###
# RUN 129
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3084
# vertohor 0.1222
# grasscover 0.4298
# treecover 0.2617
# ###
# RUN 130
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4095
# vertohor 0.1222
# grasscover 0.4995
# treecover 0.091
# ###
# RUN 131
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4856
# vertohor 0.293
# grasscover 0.2278
# treecover 0.2865
# ###
# RUN 132
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.6556
# vertohor 0.293
# grasscover 0.1769
# treecover 0.1674
# ###
# RUN 133
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1286
# vertohor 0.3571
# grasscover 0.5544
# treecover 0.317
# ###
# RUN 134
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1836
# vertohor 0.3193
# grasscover 0.365
# treecover 0.4514
# ###
# RUN 135
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2724
# vertohor 0.2687
# grasscover 0.3924
# treecover 0.3353
# ###
# RUN 136
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3456
# vertohor 0.293
# grasscover 0.3389
# treecover 0.3156
# ###
# RUN 137
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3696
# vertohor 0.3494
# grasscover 0.3578
# treecover 0.2726
# ###
# RUN 138
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.436
# vertohor 0.2938
# grasscover 0.3615
# treecover 0.2025
# ###
# RUN 139
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3299
# vertohor 0.3217
# grasscover 0.4807
# treecover 0.1894
# ###
# RUN 140
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1049
# vertohor 0.3861
# grasscover 0.5677
# treecover 0.3274
# ###
# RUN 141
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2948
# vertohor 0.3494
# grasscover 0.4863
# treecover 0.2188
# ###
# RUN 142
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2211
# vertohor 0.3494
# grasscover 0.3109
# treecover 0.4681
# ###
# RUN 143
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.134
# vertohor 0.1561
# grasscover 0.2447
# treecover 0.6212
# ###
# RUN 144
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4968
# vertohor 0.1561
# grasscover 0.2045
# treecover 0.2987
# ###
# RUN 145
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4173
# vertohor 0.1192
# grasscover 0.1608
# treecover 0.4218
# ###
# RUN 146
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4533
# vertohor 0.2011
# grasscover 0.242
# treecover 0.3047
# ###
# RUN 147
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1276
# vertohor 0.2941
# grasscover 0.5791
# treecover 0.2933
# ###
# RUN 148
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2519
# vertohor 0.1561
# grasscover 0.4067
# treecover 0.3414
# ###
# RUN 149
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3808
# vertohor 0.237
# grasscover 0.293
# treecover 0.3262
# ###
# RUN 150
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5464
# vertohor 0.3618
# grasscover 0.1382
# treecover 0.3154
# ###
# RUN 151
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2932
# vertohor 0.1859
# grasscover 0.3958
# treecover 0.311
# ###
# RUN 152
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1625
# vertohor 0.1556
# grasscover 0.6816
# treecover 0.1558
# ###
# RUN 153
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3027
# vertohor 0.237
# grasscover 0.2673
# treecover 0.43
# ###
# RUN 154
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2656
# vertohor 0.237
# grasscover 0.4874
# treecover 0.247
# ###
# RUN 155
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4434
# vertohor 0.3853
# grasscover 0.1317
# treecover 0.4249
# ###
# RUN 156
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1712
# vertohor 0.3853
# grasscover 0.4386
# treecover 0.3902
# ###
# RUN 157
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5007
# vertohor 0.5812
# grasscover 0.1599
# treecover 0.3394
# ###
# RUN 158
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.433
# vertohor 0.4101
# grasscover 0.2535
# treecover 0.3134
# ###
# RUN 159
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3026
# vertohor 0.3089
# grasscover 0.2676
# treecover 0.4298
# ###
# RUN 160
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5887
# vertohor 0.3853
# grasscover 0.0925
# treecover 0.3187
# ###
# RUN 161
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.321
# vertohor 0.4487
# grasscover 0.3703
# treecover 0.3087
# ###
# RUN 162
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1962
# vertohor 0.3314
# grasscover 0.7196
# treecover 0.0842
# ###
# RUN 163
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5554
# vertohor 0.4233
# grasscover 0.2824
# treecover 0.1621
# ###
# RUN 164
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4143
# vertohor 0.6062
# grasscover 0.1924
# treecover 0.3933
# ###
# RUN 165
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2219
# vertohor 0.4487
# grasscover 0.4151
# treecover 0.363
# ###
# RUN 166
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5997
# vertohor 0.4487
# grasscover 0.2089
# treecover 0.1914
# ###
# RUN 167
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2595
# vertohor 0.2826
# grasscover 0.4665
# treecover 0.274
# ###
# RUN 168
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2825
# vertohor 0.2826
# grasscover 0.4623
# treecover 0.2552
# ###
# RUN 169
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2927
# vertohor 0.2243
# grasscover 0.3533
# treecover 0.354
# ###
# RUN 170
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2094
# vertohor 0.4686
# grasscover 0.5636
# treecover 0.227
# ###
# RUN 171
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2874
# vertohor 0.2999
# grasscover 0.223
# treecover 0.4896
# ###
# RUN 172
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5901
# vertohor 0.2826
# grasscover 0.1559
# treecover 0.254
# ###
# RUN 173
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.325
# vertohor 0.4077
# grasscover 0.495
# treecover 0.18
# ###
# RUN 174
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4933
# vertohor 0.4896
# grasscover 0.2706
# treecover 0.2361
# ###
# RUN 175
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.399
# vertohor 0.2351
# grasscover 0.0864
# treecover 0.5147
# ###
# RUN 176
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2229
# vertohor 0.393
# grasscover 0.4064
# treecover 0.3707
# ###
# RUN 177
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3195
# vertohor 0.4077
# grasscover 0.4847
# treecover 0.1958
# ###
# RUN 178
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2025
# vertohor 0.4077
# grasscover 0.6276
# treecover 0.1699
# ###
# RUN 179
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2938
# vertohor 0.4552
# grasscover 0.5202
# treecover 0.186
# ###
# RUN 180
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.393
# vertohor 0.4552
# grasscover 0.2634
# treecover 0.3436
# ###
# RUN 181
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4683
# vertohor 0.6458
# grasscover 0.4062
# treecover 0.1255
# ###
# RUN 182
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5554
# vertohor 0.3201
# grasscover 0.25
# treecover 0.1946
# ###
# RUN 183
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3807
# vertohor 0.4766
# grasscover 0.4962
# treecover 0.1231
# ###
# RUN 184
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2308
# vertohor 0.4552
# grasscover 0.329
# treecover 0.4402
# ###
# RUN 185
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1779
# vertohor 0.5562
# grasscover 0.3745
# treecover 0.4476
# ###
# RUN 186
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2877
# vertohor 0.3391
# grasscover 0.3506
# treecover 0.3616
# ###
# RUN 187
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5986
# vertohor 0.6898
# grasscover 0.2592
# treecover 0.1422
# ###
# RUN 188
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3157
# vertohor 0.5068
# grasscover 0.3352
# treecover 0.3492
# ###
# RUN 189
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.6102
# vertohor 0.5562
# grasscover 0.1435
# treecover 0.2463
# ###
# RUN 190
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3204
# vertohor 0.5562
# grasscover 0.3523
# treecover 0.3273
# ###
# RUN 191
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0902
# vertohor 0.2553
# grasscover 0.4128
# treecover 0.497
# ###
# RUN 192
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3856
# vertohor 0.2553
# grasscover 0.2031
# treecover 0.4113
# ###
# RUN 193
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1353
# vertohor 0.2248
# grasscover 0.3291
# treecover 0.5356
# ###
# RUN 194
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4011
# vertohor 0.5282
# grasscover 0.3506
# treecover 0.2483
# ###
# RUN 195
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3001
# vertohor 0.3163
# grasscover 0.3356
# treecover 0.3643
# ###
# RUN 196
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4662
# vertohor 0.2553
# grasscover 0.3742
# treecover 0.1596
# ###
# RUN 197
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2459
# vertohor 0.5481
# grasscover 0.3168
# treecover 0.4373
# ###
# RUN 198
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2324
# vertohor 0.6017
# grasscover 0.197
# treecover 0.5707
# ###
# RUN 199
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1336
# vertohor 0.2708
# grasscover 0.5339
# treecover 0.3325
# ###
# RUN 200
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4538
# vertohor 0.4864
# grasscover 0.1831
# treecover 0.3631
# ###
# RUN 201
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4519
# vertohor 0.5481
# grasscover 0.3536
# treecover 0.1944
# ###
# RUN 202
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5135
# vertohor 0.5481
# grasscover 0.4183
# treecover 0.0682
# ###
# RUN 203
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3543
# vertohor 0.4801
# grasscover 0.2969
# treecover 0.3489
# ###
# RUN 204
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.6244
# vertohor 0.4801
# grasscover 0.1176
# treecover 0.258
# ###
# RUN 205
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2925
# vertohor 0.4374
# grasscover 0.3228
# treecover 0.3846
# ###
# RUN 206
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3061
# vertohor 0.3692
# grasscover 0.3302
# treecover 0.3638
# ###
# RUN 207
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.273
# vertohor 0.316
# grasscover 0.1856
# treecover 0.5414
# ###
# RUN 208
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3083
# vertohor 0.4801
# grasscover 0.587
# treecover 0.1047
# ###
# RUN 209
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2292
# vertohor 0.2111
# grasscover 0.3942
# treecover 0.3767
# ###
# RUN 210
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1924
# vertohor 0.2264
# grasscover 0.3014
# treecover 0.5062
# ###
# RUN 211
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2562
# vertohor 0.2969
# grasscover 0.5204
# treecover 0.2233
# ###
# RUN 212
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2121
# vertohor 0.33
# grasscover 0.3708
# treecover 0.4171
# ###
# RUN 213
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0957
# vertohor 0.2111
# grasscover 0.1984
# treecover 0.7059
# ###
# RUN 214
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1822
# vertohor 0.2111
# grasscover 0.4911
# treecover 0.3267
# ###
# RUN 215
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.6512
# vertohor 0.2792
# grasscover 0.1251
# treecover 0.2237
# ###
# RUN 216
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3732
# vertohor 0.2792
# grasscover 0.4402
# treecover 0.1866
# ###
# RUN 217
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1311
# vertohor 0.3408
# grasscover 0.5126
# treecover 0.3563
# ###
# RUN 218
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5673
# vertohor 0.154
# grasscover 0.2323
# treecover 0.2005
# ###
# RUN 219
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4012
# vertohor 0.3161
# grasscover 0.2225
# treecover 0.3763
# ###
# RUN 220
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1496
# vertohor 0.2792
# grasscover 0.3725
# treecover 0.478
# ###
# RUN 221
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0809
# vertohor 0.2367
# grasscover 0.5238
# treecover 0.3953
# ###
# RUN 222
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2511
# vertohor 0.1785
# grasscover 0.4285
# treecover 0.3204
# ###
# RUN 223
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1923
# vertohor 0.3974
# grasscover 0.6879
# treecover 0.1198
# ###
# RUN 224
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3681
# vertohor 0.1955
# grasscover 0.3906
# treecover 0.2413
# ###
# RUN 225
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2962
# vertohor 0.2367
# grasscover 0.3246
# treecover 0.3792
# ###
# RUN 226
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4648
# vertohor 0.2367
# grasscover 0.4656
# treecover 0.0696
# ###
# RUN 227
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4726
# vertohor 0.4277
# grasscover 0.2314
# treecover 0.296
# ###
# RUN 228
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2815
# vertohor 0.4277
# grasscover 0.1648
# treecover 0.5537
# ###
# RUN 229
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.081
# vertohor 0.501
# grasscover 0.6957
# treecover 0.2233
# ###
# RUN 230
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2659
# vertohor 0.3498
# grasscover 0.3885
# treecover 0.3456
# ###
# RUN 231
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4547
# vertohor 0.4723
# grasscover 0.3961
# treecover 0.1491
# ###
# RUN 232
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2503
# vertohor 0.4277
# grasscover 0.4873
# treecover 0.2624
# ###
# RUN 233
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1384
# vertohor 0.4816
# grasscover 0.1407
# treecover 0.7209
# ###
# RUN 234
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1858
# vertohor 0.3919
# grasscover 0.5911
# treecover 0.223
# ###
# RUN 235
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5869
# vertohor 0.5634
# grasscover 0.2147
# treecover 0.1983
# ###
# RUN 236
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4204
# vertohor 0.4196
# grasscover 0.3555
# treecover 0.2241
# ###
# RUN 237
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3619
# vertohor 0.4816
# grasscover 0.2758
# treecover 0.3623
# ###
# RUN 238
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5817
# vertohor 0.4816
# grasscover 0.3424
# treecover 0.076
# ###
# RUN 239
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5391
# vertohor 0.4328
# grasscover 0.1879
# treecover 0.273
# ###
# RUN 240
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2224
# vertohor 0.4328
# grasscover 0.3048
# treecover 0.4729
# ###
# RUN 241
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3126
# vertohor 0.4616
# grasscover 0.2911
# treecover 0.3963
# ###
# RUN 242
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2001
# vertohor 0.1336
# grasscover 0.6345
# treecover 0.1654
# ###
# RUN 243
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.582
# vertohor 0.4212
# grasscover 0.294
# treecover 0.124
# ###
# RUN 244
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3306
# vertohor 0.4328
# grasscover 0.4684
# treecover 0.2009
# ###
# RUN 245
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1638
# vertohor 0.1411
# grasscover 0.3277
# treecover 0.5086
# ###
# RUN 246
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1635
# vertohor 0.1282
# grasscover 0.6318
# treecover 0.2047
# ###
# RUN 247
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3152
# vertohor 0.4485
# grasscover 0.2881
# treecover 0.3967
# ###
# RUN 248
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2254
# vertohor 0.1477
# grasscover 0.5679
# treecover 0.2067
# ###
# RUN 249
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3772
# vertohor 0.1411
# grasscover 0.5201
# treecover 0.1027
# ###
# RUN 250
# ...
# bldheight 4.1367
# blddensity 0.4982
# vertohor 0.1676
# grasscover 0.339
# treecover 0.1629
# ###
# RUN 1116
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3968
# vertohor 0.1676
# grasscover 0.3322
# treecover 0.271
# ###
# RUN 1117
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2632
# vertohor 0.2463
# grasscover 0.6209
# treecover 0.1159
# ###
# RUN 1118
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2198
# vertohor 0.1954
# grasscover 0.3311
# treecover 0.4491
# ###
# RUN 1119
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4758
# vertohor 0.1751
# grasscover 0.1675
# treecover 0.3567
# ###
# RUN 1120
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0795
# vertohor 0.1676
# grasscover 0.4052
# treecover 0.5152
# ###
# RUN 1121
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3692
# vertohor 0.3011
# grasscover 0.1672
# treecover 0.4635
# ###
# RUN 1122
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4566
# vertohor 0.204
# grasscover 0.3095
# treecover 0.2339
# ###
# RUN 1123
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2055
# vertohor 0.2631
# grasscover 0.3888
# treecover 0.4057
# ###
# RUN 1124
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3581
# vertohor 0.2828
# grasscover 0.0909
# treecover 0.551
# ###
# RUN 1125
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.465
# vertohor 0.3011
# grasscover 0.3316
# treecover 0.2034
# ###
# RUN 1126
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2715
# vertohor 0.3011
# grasscover 0.444
# treecover 0.2845
# ###
# RUN 1127
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4076
# vertohor 0.5156
# grasscover 0.0858
# treecover 0.5066
# ###
# RUN 1128
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3022
# vertohor 0.5156
# grasscover 0.1389
# treecover 0.5589
# ###
# RUN 1129
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1083
# vertohor 0.4177
# grasscover 0.6357
# treecover 0.2561
# ###
# RUN 1130
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1307
# vertohor 0.1042
# grasscover 0.4363
# treecover 0.433
# ###
# RUN 1131
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1994
# vertohor 0.7476
# grasscover 0.466
# treecover 0.3347
# ###
# RUN 1132
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5385
# vertohor 0.5156
# grasscover 0.329
# treecover 0.1325
# ###
# RUN 1133
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4097
# vertohor 0.1213
# grasscover 0.2981
# treecover 0.2922
# ###
# RUN 1134
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1006
# vertohor 0.2446
# grasscover 0.5532
# treecover 0.3462
# ###
# RUN 1135
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3855
# vertohor 0.558
# grasscover 0.2686
# treecover 0.3459
# ###
# RUN 1136
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1409
# vertohor 0.0727
# grasscover 0.2565
# treecover 0.6026
# ###
# RUN 1137
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1522
# vertohor 0.1213
# grasscover 0.6653
# treecover 0.1825
# ###
# RUN 1138
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4465
# vertohor 0.1213
# grasscover 0.2449
# treecover 0.3085
# ###
# RUN 1139
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2285
# vertohor 0.365
# grasscover 0.3078
# treecover 0.4638
# ###
# RUN 1140
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5646
# vertohor 0.365
# grasscover 0.1502
# treecover 0.2852
# ###
# RUN 1141
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2042
# vertohor 0.59
# grasscover 0.2132
# treecover 0.5826
# ###
# RUN 1142
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5467
# vertohor 0.3902
# grasscover 0.3665
# treecover 0.0868
# ###
# RUN 1143
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1729
# vertohor 0.2775
# grasscover 0.4827
# treecover 0.3444
# ###
# RUN 1144
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3834
# vertohor 0.365
# grasscover 0.4716
# treecover 0.145
# ###
# RUN 1145
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1454
# vertohor 0.4166
# grasscover 0.755
# treecover 0.0996
# ###
# RUN 1146
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1562
# vertohor 0.2995
# grasscover 0.1941
# treecover 0.6497
# ###
# RUN 1147
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2875
# vertohor 0.3908
# grasscover 0.5048
# treecover 0.2077
# ###
# RUN 1148
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4218
# vertohor 0.6157
# grasscover 0.3048
# treecover 0.2734
# ###
# RUN 1149
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1587
# vertohor 0.4166
# grasscover 0.2214
# treecover 0.6198
# ###
# RUN 1150
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.364
# vertohor 0.4166
# grasscover 0.1891
# treecover 0.4469
# ###
# RUN 1151
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3976
# vertohor 0.2211
# grasscover 0.1495
# treecover 0.4528
# ###
# RUN 1152
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2308
# vertohor 0.2211
# grasscover 0.641
# treecover 0.1282
# ###
# RUN 1153
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3999
# vertohor 0.1818
# grasscover 0.2623
# treecover 0.3379
# ###
# RUN 1154
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5361
# vertohor 0.4278
# grasscover 0.2502
# treecover 0.2136
# ###
# RUN 1155
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2879
# vertohor 0.2353
# grasscover 0.2442
# treecover 0.4679
# ###
# RUN 1156
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3381
# vertohor 0.2211
# grasscover 0.4018
# treecover 0.2601
# ###
# RUN 1157
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3661
# vertohor 0.3839
# grasscover 0.2498
# treecover 0.384
# ###
# RUN 1158
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3818
# vertohor 0.4476
# grasscover 0.2887
# treecover 0.3295
# ###
# RUN 1159
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2515
# vertohor 0.1913
# grasscover 0.4391
# treecover 0.3093
# ###
# RUN 1160
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1343
# vertohor 0.3692
# grasscover 0.4566
# treecover 0.4092
# ###
# RUN 1161
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2102
# vertohor 0.3839
# grasscover 0.4319
# treecover 0.3579
# ###
# RUN 1162
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.293
# vertohor 0.3839
# grasscover 0.3551
# treecover 0.3518
# ###
# RUN 1163
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.5423
# vertohor 0.2731
# grasscover 0.206
# treecover 0.2517
# ###
# RUN 1164
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3829
# vertohor 0.2731
# grasscover 0.0734
# treecover 0.5437
# ###
# RUN 1165
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1519
# vertohor 0.3737
# grasscover 0.3671
# treecover 0.481
# ###
# RUN 1166
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2651
# vertohor 0.1088
# grasscover 0.433
# treecover 0.3019
# ###
# RUN 1167
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3904
# vertohor 0.2808
# grasscover 0.1506
# treecover 0.459
# ###
# RUN 1168
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3442
# vertohor 0.2731
# grasscover 0.2481
# treecover 0.4078
# ###
# RUN 1169
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3649
# vertohor 0.1708
# grasscover 0.2802
# treecover 0.3549
# ###
# RUN 1170
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2898
# vertohor 0.1125
# grasscover 0.3304
# treecover 0.3798
# ###
# RUN 1171
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.179
# vertohor 0.3881
# grasscover 0.3073
# treecover 0.5137
# ###
# RUN 1172
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4489
# vertohor 0.1624
# grasscover 0.2603
# treecover 0.2908
# ###
# RUN 1173
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4367
# vertohor 0.1708
# grasscover 0.3678
# treecover 0.1955
# ###
# RUN 1174
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.167
# vertohor 0.1708
# grasscover 0.3652
# treecover 0.4678
# ###
# RUN 1175
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4168
# vertohor 0.5338
# grasscover 0.1117
# treecover 0.4714
# ###
# RUN 1176
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3795
# vertohor 0.5338
# grasscover 0.5273
# treecover 0.0932
# ###
# RUN 1177
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3261
# vertohor 0.296
# grasscover 0.159
# treecover 0.5148
# ###
# RUN 1178
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3697
# vertohor 0.5188
# grasscover 0.1894
# treecover 0.4409
# ###
# RUN 1179
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4803
# vertohor 0.362
# grasscover 0.2707
# treecover 0.249
# ###
# RUN 1180
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2787
# vertohor 0.5338
# grasscover 0.4717
# treecover 0.2496
# ###
# RUN 1181
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4011
# vertohor 0.2237
# grasscover 0.4339
# treecover 0.165
# ###
# RUN 1182
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4915
# vertohor 0.3482
# grasscover 0.1537
# treecover 0.3548
# ###
# RUN 1183
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2077
# vertohor 0.2343
# grasscover 0.5058
# treecover 0.2865
# ###
# RUN 1184
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1023
# vertohor 0.2836
# grasscover 0.5466
# treecover 0.3511
# ###
# RUN 1185
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.0658
# vertohor 0.2237
# grasscover 0.4928
# treecover 0.4413
# ###
# RUN 1186
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1994
# vertohor 0.2237
# grasscover 0.6929
# treecover 0.1077
# ###
# RUN 1187
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.237
# vertohor 0.4005
# grasscover 0.2908
# treecover 0.4722
# ###
# RUN 1188
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2891
# vertohor 0.4005
# grasscover 0.155
# treecover 0.5559
# ###
# RUN 1189
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2227
# vertohor 0.4428
# grasscover 0.2666
# treecover 0.5107
# ###
# RUN 1190
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2727
# vertohor 0.3931
# grasscover 0.3421
# treecover 0.3852
# ###
# RUN 1191
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2931
# vertohor 0.5302
# grasscover 0.5859
# treecover 0.1211
# ###
# RUN 1192
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.3053
# vertohor 0.4005
# grasscover 0.2751
# treecover 0.4196
# ###
# RUN 1193
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4409
# vertohor 0.5997
# grasscover 0.1348
# treecover 0.4242
# ###
# RUN 1194
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.4348
# vertohor 0.5226
# grasscover 0.2947
# treecover 0.2705
# ###
# RUN 1195
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1148
# vertohor 0.607
# grasscover 0.2995
# treecover 0.5856
# ###
# RUN 1196
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1972
# vertohor 0.4352
# grasscover 0.4329
# treecover 0.3698
# ###
# RUN 1197
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.2046
# vertohor 0.5997
# grasscover 0.4196
# treecover 0.3759
# ###
# RUN 1198
# Some issue with inputs.
# bldheight 4.1367
# blddensity 0.1513
# vertohor 0.5997
# grasscover 0.3947
# treecover 0.4539
# ###
# RUN 1199
# Simulating new temperature and humidity values for 1 days from 1/1.
# Simulating Day 1
# Some issue with inputs.

# %%
from SALib.analyze import sobol

# Perform analysis
Si = sobol.analyze(test_problem, Y, calc_second_order=True, print_to_console=True)

print("{:28s} {:>5s} {:>5s} {:>12s}".format("Name", "1st", "2nd", "Total", "Mean of Input"))
for name, s1, s2, st, mean in zip(test_problem['names'], Si['S1'], Si['S2'], Si['ST'], param.mean(axis=0)):
    print("{:28s} {:=5.2f} {:=5.2f} ({:=12.2f})".format(name, s1, st, mean)) 



print("************")

columns = []
bounds = []

for col in test_problem['names']:
    columns.append(col)
    
for b in test_problem['bounds']:
        bounds.append(b) 


rows = []
data =  []    
 
cnt=0
for key, value in Si.items():
    rows.append(key)
    data.append(value.round(3))
    cnt+=1
    if cnt > 3:
        break
        

total_Si, first_Si, second_Si = Si.to_df()
print(first_Si)
print(second_Si)
print(total_Si)


# https://github.com/SALib/SALib/issues/206
# Out:
#             ST  ST_conf
# bldheight  NaN      NaN
# blddensity NaN      NaN
# vertohor   NaN      NaN
# grasscover NaN      NaN
# treecover  NaN      NaN
#             S1  S1_conf
# bldheight  NaN      NaN
# blddensity NaN      NaN
# vertohor   NaN      NaN
# grasscover NaN      NaN
# treecover  NaN      NaN
#                           S2  S2_conf
# (bldheight, blddensity)  NaN      NaN
# (bldheight, vertohor)    NaN      NaN
# (bldheight, grasscover)  NaN      NaN
# (bldheight, treecover)   NaN      NaN
# (blddensity, vertohor)   NaN      NaN
# (blddensity, grasscover) NaN      NaN
# (blddensity, treecover)  NaN      NaN
# (vertohor, grasscover)   NaN      NaN
# (vertohor, treecover)    NaN      NaN
# (grasscover, treecover)  NaN      NaN
# Name                           1st   2nd        Total
# bldheight                      nan   nan (       51.71)
# blddensity                     nan   nan (        0.34)
# vertohor                       nan   nan (        0.35)
# grasscover                     nan   nan (        0.33)
# treecover                      nan   nan (        0.33)
# ************
#             S1  S1_conf
# bldheight  NaN      NaN
# blddensity NaN      NaN
# vertohor   NaN      NaN
# grasscover NaN      NaN
# treecover  NaN      NaN
#                           S2  S2_conf
# (bldheight, blddensity)  NaN      NaN
# (bldheight, vertohor)    NaN      NaN
# (bldheight, grasscover)  NaN      NaN
# (bldheight, treecover)   NaN      NaN
# (blddensity, vertohor)   NaN      NaN
# (blddensity, grasscover) NaN      NaN
# (blddensity, treecover)  NaN      NaN
# (vertohor, grasscover)   NaN      NaN
# (vertohor, treecover)    NaN      NaN
# (grasscover, treecover)  NaN      NaN
#             ST  ST_conf
# bldheight  NaN      NaN
# blddensity NaN      NaN
# vertohor   NaN      NaN
# grasscover NaN      NaN
# treecover  NaN      NaN

# %%
pd.DataFrame(Y)
# Out:
#        0
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# ...   ..
# 1195 NaN
# 1196 NaN
# 1197 NaN
# 1198 NaN
# 1199 NaN
#
# [1200 rows x 1 columns]

# %%
Si
# Out:
# {'S1': array([nan, nan, nan, nan, nan]),
#  'S1_conf': array([nan, nan, nan, nan, nan]),
#  'ST': array([nan, nan, nan, nan, nan]),
#  'ST_conf': array([nan, nan, nan, nan, nan]),
#  'S2': array([[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]]),
#  'S2_conf': array([[nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan],
#         [nan, nan, nan, nan, nan]])}

# %%
Si_filter = {k:Si[k] for k in ['ST','ST_conf','S1','S1_conf', 'S2', 'S2_conf']}
Si_df = pd.DataFrame(Si_filter, index=test_problem['names'])
Si_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 2
#       1 Si_filter = {k:Si[k] for k in ['ST','ST_conf','S1','S1_conf', 'S2', 'S2_conf']}
# ----> 2 Si_df = pd.DataFrame(Si_filter, index=test_problem['names'])
#       3 Si_df
#
# File c:\Python311\Lib\site-packages\pandas\core\frame.py:664, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     658     mgr = self._init_mgr(
#     659         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     660     )
#     662 elif isinstance(data, dict):
#     663     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665 elif isinstance(data, ma.MaskedArray):
#     666     import numpy.ma.mrecords as mrecords
#
# File c:\Python311\Lib\site-packages\pandas\core\internals\construction.py:493, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     489     else:
#     490         # dtype check to exclude e.g. range objects, scalars
#     491         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 493 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Python311\Lib\site-packages\pandas\core\internals\construction.py:123, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     120         index = ensure_index(index)
#     122     # don't force copy because getting jammed in an ndarray anyway
# --> 123     arrays = _homogenize(arrays, index, dtype)
#     124     # _homogenize ensures
#     125     #  - all(len(x) == len(index) for x in arrays)
#     126     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     129
#     130 else:
#     131     index = ensure_index(index)
#
# File c:\Python311\Lib\site-packages\pandas\core\internals\construction.py:617, in _homogenize(data, index, dtype)
#     614             val = dict(val)
#     615         val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 617     val = sanitize_array(
#     618         val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     619     )
#     620     com.require_length_match(val, index)
#     622 homogenized.append(val)
#
# File c:\Python311\Lib\site-packages\pandas\core\construction.py:647, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     644             subarr = cast(np.ndarray, subarr)
#     645             subarr = maybe_infer_to_datetimelike(subarr)
# --> 647 subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     649 if isinstance(subarr, np.ndarray):
#     650     # at this point we should have dtype be None or subarr.dtype == dtype
#     651     dtype = cast(np.dtype, dtype)
#
# File c:\Python311\Lib\site-packages\pandas\core\construction.py:698, in _sanitize_ndim(result, data, dtype, index, allow_2d)
#     696     if allow_2d:
#     697         return result
# --> 698     raise ValueError("Data must be 1-dimensional")
#     699 if is_object_dtype(dtype) and isinstance(dtype, ExtensionDtype):
#     700     # i.e. PandasDtype("O")
#     702     result = com.asarray_tuplesafe(data, dtype=np.dtype("object"))
#
# ValueError: Data must be 1-dimensional

# %%
print(Si_df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print(Si_df.columns)
#
# NameError: name 'Si_df' is not defined

# %%
import matplotlib.pyplot as plt

# %matplotlib inline
fig, ax = plt.subplots(1)

indices = Si_df[['S1', 'S2', 'ST']]
err = Si_df[['S1_conf', 'S2_conf', 'ST_conf']]

indices.plot.bar(yerr=err.values.T,ax=ax)
fig.set_size_inches(8,4)

plt.show()

# Save figure
name = "bar_plot_S1_S2_ST"
#fig.savefig(name + '.pdf', bbox_inches='tight', pad_inches=0.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 6
#       3 get_ipython().run_line_magic('matplotlib', 'inline')
#       4 fig, ax = plt.subplots(1)
# ----> 6 indices = Si_df[['S1', 'S2', 'ST']]
#       7 err = Si_df[['S1_conf', 'S2_conf', 'ST_conf']]
#       9 indices.plot.bar(yerr=err.values.T,ax=ax)
#
# NameError: name 'Si_df' is not defined

# %%
import itertools
from math import pi
import seaborn as sns
sns.set_style('whitegrid')
from math import pi
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def normalize(x, xmin, xmax):
    return (x-xmin)/(xmax-xmin)


def plot_circles(ax, locs, names, max_s, stats, smax, smin, fc, ec, lw,
                 zorder):
    s = np.asarray([stats[name] for name in names])
    s = 0.01 + max_s * np.sqrt(normalize(s, smin, smax))

    fill = True
    for loc, name, si in zip(locs, names, s):
        if fc=='w':
            fill=False
        else:
            ec='none'

        x = np.cos(loc)
        y = np.sin(loc)

        circle = plt.Circle((x,y), radius=si, ec=ec, fc=fc, transform=ax.transData._b,
                            zorder=zorder, lw=lw, fill=True)
        ax.add_artist(circle)


def filter(sobol_indices, names, locs, criterion, threshold):
    if criterion in ['ST', 'S1', 'S2']:
        data = sobol_indices[criterion]
        data = np.abs(data)
        data = data.flatten() # flatten in case of S2
        # TODO:: remove nans

        filtered = ([(name, locs[i]) for i, name in enumerate(names) if
                     data[i]>threshold])
        filtered_names, filtered_locs = zip(*filtered)
    elif criterion in ['ST_conf', 'S1_conf', 'S2_conf']:
        raise NotImplementedError
    else:
        raise ValueError('unknown value for criterion')

    return filtered_names, filtered_locs


def plot_sobol_indices(test_problem, sobol_indices, criterion='ST', threshold=0.01):
    '''plot sobol indices on a radial plot

    Parameters
    ----------
    sobol_indices : dict
                    the return from SAlib
    criterion : {'ST', 'S1', 'S2', 'ST_conf', 'S1_conf', 'S2_conf'}, optional
    threshold : float
                only visualize variables with criterion larger than cutoff

    '''
    max_linewidth_s2 = 15#25*1.8
    max_s_radius = 0.3

    # prepare data
    # use the absolute values of all the indices
    #sobol_indices = {key:np.abs(stats) for key, stats in sobol_indices.items()}

    # dataframe with ST and S1
    sobol_stats = {key:sobol_indices[key] for key in ['ST', 'S1']}
    sobol_stats = pd.DataFrame(sobol_stats, index=test_problem['names'])

    smax = sobol_stats.max().max()
    smin = sobol_stats.min().min()

    # dataframe with s2
    s2 = pd.DataFrame(sobol_indices['S2'], index=test_problem['names'],
                      columns=test_problem['names'])
    s2[s2<0.0]=0. #Set negative values to 0 (artifact from small sample sizes)
    s2max = s2.max().max()
    s2min = s2.min().min()

    names = test_problem['names']
    n = len(names)
   
    ticklocs = np.linspace(0, 2*pi, n+1)
    locs = ticklocs[0:-1]


    filtered_names, filtered_locs = filter(sobol_indices, names, locs,
                                           criterion, threshold)

    # setup figure
    fig = plt.figure()
    ax = fig.add_subplot(111, polar=True)
    ax.grid(False)
    ax.spines['polar'].set_visible(False)
   
    ax.set_xticks(ticklocs[0:len(names)])

    ax.set_xticklabels(names)
    ax.set_yticklabels([])
    
    ax.set_ylim(top=1.4)
    legend(ax)

    # plot ST
    plot_circles(ax, filtered_locs, filtered_names, max_s_radius,
                 sobol_stats['ST'], smax, smin, 'w', 'k', 1, 9)

    # plot S1
    plot_circles(ax, filtered_locs, filtered_names, max_s_radius,
                 sobol_stats['S1'], smax, smin, 'k', 'k', 1, 10)

    # plot S2
    for name1, name2 in itertools.combinations(zip(filtered_names, filtered_locs), 2):
        name1, loc1 = name1
        name2, loc2 = name2

        weight = s2.loc[name1, name2]
        lw = 0.5+max_linewidth_s2*normalize(weight, s2min, s2max)
        ax.plot([loc1, loc2], [1,1], c='darkgray', lw=lw, zorder=1)

    return fig


from matplotlib.legend_handler import HandlerPatch
class HandlerCircle(HandlerPatch):
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize, trans):
        center = 0.5 * width - 0.5 * xdescent, 0.5 * height - 0.5 * ydescent
        p = plt.Circle(xy=center, radius=orig_handle.radius)
        self.update_prop(p, orig_handle, legend)
        p.set_transform(trans)
        return [p]

def legend(ax):
    some_identifiers = [plt.Circle((0,0), radius=5, color='k', fill=False, lw=1),
                        plt.Circle((0,0), radius=5, color='k', fill=True),
                        plt.Line2D([0,0.5], [0,0.5], lw=8, color='darkgray')]
    ax.legend(some_identifiers, ['ST', 'S1', 'S2'],
              loc=(1,0.75), borderaxespad=0.1, mode='expand',
              handler_map={plt.Circle: HandlerCircle()})

# %%
# %matplotlib inline

fig = plot_sobol_indices(test_problem, Si, criterion='ST', threshold=0.005)
fig.set_size_inches(7,7)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 3
#       1 get_ipython().run_line_magic('matplotlib', 'inline')
# ----> 3 fig = plot_sobol_indices(test_problem,Si, criterion='ST', threshold=0.005)
#       4 fig.set_size_inches(7,7)
#       5 plt.show()
#
# Cell In[22], line 93, in plot_sobol_indices(test_problem, sobol_indices, criterion, threshold)
#      89 ticklocs = np.linspace(0, 2*pi, n+1)
#      90 locs = ticklocs[0:-1]
# ---> 93 filtered_names, filtered_locs = filter(sobol_indices, names, locs,
#      94                                        criterion, threshold)
#      96 # setup figure
#      97 fig = plt.figure()
#
# Cell In[22], line 44, in filter(sobol_indices, names, locs, criterion, threshold)
#      40     # TODO:: remove nans
#      42     filtered = ([(name, locs[i]) for i, name in enumerate(names) if
#      43                  data[i]>threshold])
# ---> 44     filtered_names, filtered_locs = zip(*filtered)
#      45 elif criterion in ['ST_conf', 'S1_conf', 'S2_conf']:
#      46     raise NotImplementedError
#
# ValueError: not enough values to unpack (expected 2, got 0)
